# %% [markdown]
# # PRCP-1024-TexasSalaryPrediction

# %% [markdown]
# ##TEAM ID:"PTID-CDS-JUL-24-1981 "
#
# ##BATCH ID:12-FEB-24-CDS-BUN-021-WDM09-BAN

# %% [markdown]
# Problem Statement
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:-Create a predictive model which will help theTexas state government team to know the payroll information of employees of the state of Texas.
#
# Task 3:-
#
# ● Who are the outliers in the salaries?
#
# ● What departments/roles have the biggest wage disparities between
# managers and employees?
#
# ● Have salaries and total compensations for some roles/ departments/
# head-count changed over time?

# %%
## Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\salary\salary.csv")
df
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# 1       RUCKER                          MORTON                          V
# 2       SPECIA JR                       JOHN                            J
# 3       SPECIA JR                       JOHN                            J
# 4       ONTIVEROS                       ESTHER
# ...                                ...                             ... ..
# 149476  WESSELS                         JOHN                            P
# 149477  WINDHAM                         EVAN                            A
# 149478  WRIGHT                          DERRICK                         C
# 149479  YOUNG                           DOUGLAS                         R
# 149480  ZUNKER                          GEORGIA                         P
#
#        CLASS CODE                                        CLASS TITLE  \
# 0        JD25      JUDGE, RETIRED                                ...
# 1        3524      GENERAL COUNSEL IV                            ...
# 2        JD25      JUDGE, RETIRED                                ...
# 3        3524      GENERAL COUNSEL IV                            ...
# 4        4504      CORREC  OFFICER IV                            ...
# ...           ...                                                ...
# 149476   6232      SECURITY OFFICER III                          ...
# 149477   0302      WEB ADMINISTRATOR III                         ...
# 149478   0130      CUSTOMER SERVICE REP I                        ...
# 149479   1572      PROGRAM SPECIALIST III                        ...
# 149480   0130      CUSTOMER SERVICE REP I                        ...
#
#               ETHNICITY           GENDER  \
# 0       WHITE            MALE
# 1       WHITE            MALE
# 2       WHITE            MALE
# 3       WHITE            MALE
# 4       HISPANIC         FEMALE
# ...                 ...              ...
# 149476  WHITE            MALE
# 149477  WHITE            FEMALE
# 149478  WHITE            MALE
# 149479  WHITE            MALE
# 149480  WHITE            FEMALE
#
#                                           STATUS EMPLOY DATE  HRLY RATE  \
# 0       URP - UNCLASSIFIED REGULAR PART-TIME        02/18/88   75.96150
# 1       CTP - CLASSIFIED TEMPORARY PART-TIME        02/01/15   81.04454
# 2       URP - UNCLASSIFIED REGULAR PART-TIME        02/01/20   75.96150
# 3       CTP - CLASSIFIED TEMPORARY PART-TIME        09/01/18   81.04453
# 4       CRF - CLASSIFIED REGULAR FULL-TIME          06/29/20    0.00000
# ...                                          ...         ...        ...
# 149476  CRF - CLASSIFIED REGULAR FULL-TIME          10/30/17    0.00000
# 149477  CRF - CLASSIFIED REGULAR FULL-TIME          07/13/15    0.00000
# 149478  CRP - CLASSIFIED REGULAR PART-TIME          10/15/12   12.93000
# 149479  CRF - CLASSIFIED REGULAR FULL-TIME          09/22/89    0.00000
# 149480  CRP - CLASSIFIED REGULAR PART-TIME          02/16/12   11.74000
#
#         HRS PER WK  MONTHLY     ANNUAL  STATE NUMBER duplicated  \
# 0             29.0  9545.82  114549.84        127717       True
# 1              4.0  1404.77   16857.24        127717       True
# 2             29.0  9545.82  114549.84         59115       True
# 3              4.0  1404.77   16857.24         59115       True
# 4             40.0  3284.27   39411.24        165030       True
# ...            ...      ...        ...           ...        ...
# 149476        40.0  2899.00   34788.00        770781        NaN
# 149477        40.0  5500.00   66000.00        847431        NaN
# 149478        20.0  1120.60   13447.20         34266        NaN
# 149479        40.0  5744.16   68929.92        123490        NaN
# 149480        20.0  1017.46   12209.52        103583        NaN
#
#         multiple_full_time_jobs combined_multiple_jobs  summed_annual_salary  \
# 0                           NaN                    NaN             131407.08
# 1                           NaN                    NaN                   NaN
# 2                           NaN                    NaN             131407.08
# 3                           NaN                    NaN                   NaN
# 4                           1.0                    NaN                   NaN
# ...                         ...                    ...                   ...
# 149476                      NaN                    NaN                   NaN
# 149477                      NaN                    NaN                   NaN
# 149478                      NaN                    NaN                   NaN
# 149479                      NaN                    NaN                   NaN
# 149480                      NaN                    NaN                   NaN
#
#        hide_from_search
# 0                   NaN
# 1                  True
# 2                   NaN
# 3                  True
# 4                   NaN
# ...                 ...
# 149476              NaN
# 149477              NaN
# 149478              NaN
# 149479              NaN
# 149480              NaN
#
# [149481 rows x 21 columns]

# %%
df.shape
# Out:
# (149481, 21)

# %%
pd.set_option("display.max_columns",None)
df
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# 1       RUCKER                          MORTON                          V
# 2       SPECIA JR                       JOHN                            J
# 3       SPECIA JR                       JOHN                            J
# 4       ONTIVEROS                       ESTHER
# ...                                ...                             ... ..
# 149476  WESSELS                         JOHN                            P
# 149477  WINDHAM                         EVAN                            A
# 149478  WRIGHT                          DERRICK                         C
# 149479  YOUNG                           DOUGLAS                         R
# 149480  ZUNKER                          GEORGIA                         P
#
#        CLASS CODE                                        CLASS TITLE  \
# 0        JD25      JUDGE, RETIRED                                ...
# 1        3524      GENERAL COUNSEL IV                            ...
# 2        JD25      JUDGE, RETIRED                                ...
# 3        3524      GENERAL COUNSEL IV                            ...
# 4        4504      CORREC  OFFICER IV                            ...
# ...           ...                                                ...
# 149476   6232      SECURITY OFFICER III                          ...
# 149477   0302      WEB ADMINISTRATOR III                         ...
# 149478   0130      CUSTOMER SERVICE REP I                        ...
# 149479   1572      PROGRAM SPECIALIST III                        ...
# 149480   0130      CUSTOMER SERVICE REP I                        ...
#
#               ETHNICITY           GENDER  \
# 0       WHITE            MALE
# 1       WHITE            MALE
# 2       WHITE            MALE
# 3       WHITE            MALE
# 4       HISPANIC         FEMALE
# ...                 ...              ...
# 149476  WHITE            MALE
# 149477  WHITE            FEMALE
# 149478  WHITE            MALE
# 149479  WHITE            MALE
# 149480  WHITE            FEMALE
#
#                                           STATUS EMPLOY DATE  HRLY RATE  \
# 0       URP - UNCLASSIFIED REGULAR PART-TIME        02/18/88   75.96150
# 1       CTP - CLASSIFIED TEMPORARY PART-TIME        02/01/15   81.04454
# 2       URP - UNCLASSIFIED REGULAR PART-TIME        02/01/20   75.96150
# 3       CTP - CLASSIFIED TEMPORARY PART-TIME        09/01/18   81.04453
# 4       CRF - CLASSIFIED REGULAR FULL-TIME          06/29/20    0.00000
# ...                                          ...         ...        ...
# 149476  CRF - CLASSIFIED REGULAR FULL-TIME          10/30/17    0.00000
# 149477  CRF - CLASSIFIED REGULAR FULL-TIME          07/13/15    0.00000
# 149478  CRP - CLASSIFIED REGULAR PART-TIME          10/15/12   12.93000
# 149479  CRF - CLASSIFIED REGULAR FULL-TIME          09/22/89    0.00000
# 149480  CRP - CLASSIFIED REGULAR PART-TIME          02/16/12   11.74000
#
#         HRS PER WK  MONTHLY     ANNUAL  STATE NUMBER duplicated  \
# 0             29.0  9545.82  114549.84        127717       True
# 1              4.0  1404.77   16857.24        127717       True
# 2             29.0  9545.82  114549.84         59115       True
# 3              4.0  1404.77   16857.24         59115       True
# 4             40.0  3284.27   39411.24        165030       True
# ...            ...      ...        ...           ...        ...
# 149476        40.0  2899.00   34788.00        770781        NaN
# 149477        40.0  5500.00   66000.00        847431        NaN
# 149478        20.0  1120.60   13447.20         34266        NaN
# 149479        40.0  5744.16   68929.92        123490        NaN
# 149480        20.0  1017.46   12209.52        103583        NaN
#
#         multiple_full_time_jobs combined_multiple_jobs  summed_annual_salary  \
# 0                           NaN                    NaN             131407.08
# 1                           NaN                    NaN                   NaN
# 2                           NaN                    NaN             131407.08
# 3                           NaN                    NaN                   NaN
# 4                           1.0                    NaN                   NaN
# ...                         ...                    ...                   ...
# 149476                      NaN                    NaN                   NaN
# 149477                      NaN                    NaN                   NaN
# 149478                      NaN                    NaN                   NaN
# 149479                      NaN                    NaN                   NaN
# 149480                      NaN                    NaN                   NaN
#
#        hide_from_search
# 0                   NaN
# 1                  True
# 2                   NaN
# 3                  True
# 4                   NaN
# ...                 ...
# 149476              NaN
# 149477              NaN
# 149478              NaN
# 149479              NaN
# 149480              NaN
#
# [149481 rows x 21 columns]

# %% [markdown]
# ### **TASK 1**
# ### Prepare a complete data analysis report on the given data.

# %%
df.head(2)
# Out:
#    AGENCY                                        AGENCY NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
#
#                         LAST NAME                      FIRST NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
#
#   CLASS CODE                                        CLASS TITLE  \
# 0   JD25      JUDGE, RETIRED                                ...
# 1   3524      GENERAL COUNSEL IV                            ...
#
#          ETHNICITY           GENDER                                    STATUS  \
# 0  WHITE            MALE             URP - UNCLASSIFIED REGULAR PART-TIME
# 1  WHITE            MALE             CTP - CLASSIFIED TEMPORARY PART-TIME
#
#   EMPLOY DATE  HRLY RATE  HRS PER WK  MONTHLY     ANNUAL  STATE NUMBER  \
# 0    02/18/88   75.96150        29.0  9545.82  114549.84        127717
# 1    02/01/15   81.04454         4.0  1404.77   16857.24        127717
#
#   duplicated  multiple_full_time_jobs combined_multiple_jobs  \
# 0       True                      NaN                    NaN
# 1       True                      NaN                    NaN
#
#    summed_annual_salary hide_from_search
# 0             131407.08              NaN
# 1                   NaN             True

# %%
df.tail(2)
# Out:
#         AGENCY                                        AGENCY NAME  \
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 149479  YOUNG                           DOUGLAS                         R
# 149480  ZUNKER                          GEORGIA                         P
#
#        CLASS CODE                                        CLASS TITLE  \
# 149479   1572      PROGRAM SPECIALIST III                        ...
# 149480   0130      CUSTOMER SERVICE REP I                        ...
#
#               ETHNICITY           GENDER  \
# 149479  WHITE            MALE
# 149480  WHITE            FEMALE
#
#                                           STATUS EMPLOY DATE  HRLY RATE  \
# 149479  CRF - CLASSIFIED REGULAR FULL-TIME          09/22/89       0.00
# 149480  CRP - CLASSIFIED REGULAR PART-TIME          02/16/12      11.74
#
#         HRS PER WK  MONTHLY    ANNUAL  STATE NUMBER duplicated  \
# 149479        40.0  5744.16  68929.92        123490        NaN
# 149480        20.0  1017.46  12209.52        103583        NaN
#
#         multiple_full_time_jobs combined_multiple_jobs  summed_annual_salary  \
# 149479                      NaN                    NaN                   NaN
# 149480                      NaN                    NaN                   NaN
#
#        hide_from_search
# 149479              NaN
# 149480              NaN

# %% [markdown]
# ## **DOMAIN ANALYSIS**
#
# This database has salary information for positions at all 113 agencies in the Texas state government. The Tribune obtained this data by requesting salary records from the state comptroller, as allowed by the Texas Public Information Act. Our main objective is to predict salary information of employees at different agencies in Texas state government using given twenty one features.
#
#
# ### 1) AGENCY:
# This likely refers to the name or identifier of the agency where the employee works. It identifies the organizational unit within which the employee is employed.
#
# ### 2) AGENCY NAME:
# This could be a more descriptive version of the "AGENCY" column, providing the full name or official title of the agency.
#
# ### 3)LAST NAME, FIRST NAME, MI:
# These columns together typically represent the employee's name:
#
# LAST NAME: Employee's last name.
# FIRST NAME: Employee's first name.
# MI: Middle initial of the employee (if applicable).
# CLASS CODE: This column likely represents the classification code or category of the employee's position. It helps in categorizing different types of roles within the agency.
#
# ### 4) CLASS TITLE:
# This column usually contains the job title or official title of the employee's position within the agency.
#
# ### 5) ETHNICITY:
# This column typically records the ethnicity or race information of the employee, often for diversity reporting and compliance purposes.
#
# ### 6) GENDER:
# This column indicates the gender of the employee.
#
# ### 7) STATUS:
# This could indicate the employment status of the employee (e.g., full-time, part-time, temporary).
#
# ### 8) EMPLOY DATE:
# The date when the employee started their current employment or the agency's records began for the employee.
#
# ### 9) HRLY RATE:
# Hourly rate of pay for the employee.
#
# ### 10) HRS PER WK:
# Hours per week that the employee is scheduled to work.
#
# ### 11) MONTHLY:
# Monthly salary or earnings for the employee.
#
# ### 12) ANNUAL:
# Annual salary or earnings for the employee.
#
# ### 13) STATE NUMBER:
# A unique identifier or number associated with the employee's record within the state or agency system.
#
# ### 14) duplicated:
# This might indicate if there are any duplicated records for the employee in the dataset.
#
# ### 15) multiple_full_time_jobs:
# This could indicate if the employee holds multiple full-time jobs within the agency.
#
# ### 16) combined_multiple_jobs:
# Possibly indicates if the employee's multiple job roles have been combined for reporting purposes.
#
# ### 17) summed_annual_salary:
# This could be the aggregated or calculated annual salary considering all job roles or earnings.
#
# ### 18) hide_from_search:
# This might indicate if the employee's information should be excluded or hidden from certain searches or reports.
#
# ## Domain Analysis:
# ### Data Integrity and Quality:
# Check for completeness and accuracy of each field. Ensure there are no missing values or inconsistencies, especially in sensitive fields like ethnicity and gender.
#
# ### Employee Demographics:
# Analyze ethnicity, gender distribution to understand diversity within the agency.
#
# ### Employment Status and Salary:
# Look at the distribution of full-time vs. part-time employees, examine salary ranges and hourly rates to identify trends or disparities.
#
# ### Job Roles and Classification:
# Evaluate the distribution of job titles (CLASS TITLE) and classifications (CLASS CODE) to understand the hierarchy and diversity of roles within the agency.
#
# ### Data Cleanup and Deduplication:
# Address any duplicates or inconsistencies flagged by the 'duplicated' field.
#
# ### Multiple Job Holders:
# Investigate employees flagged with 'multiple_full_time_jobs' and 'combined_multiple_jobs' to understand workload distribution and salary implications.
#
# ### Salary Aggregation:
# Utilize 'summed_annual_salary' to analyze total salary expenditures across different groups or departments.
#
# ### Privacy and Access Control:
# Consider implications of 'hide_from_search' for data privacy and access management

# %%
pd.set_option("display.max_rows",None)
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149481 entries, 0 to 149480
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   AGENCY                   149481 non-null  int64
#  1   AGENCY NAME              149481 non-null  object
#  2   LAST NAME                149481 non-null  object
#  3   FIRST NAME               149481 non-null  object
#  4   MI                       149481 non-null  object
#  5   CLASS CODE               149481 non-null  object
#  6   CLASS TITLE              149481 non-null  object
#  7   ETHNICITY                149481 non-null  object
#  8   GENDER                   149481 non-null  object
#  9   STATUS                   149481 non-null  object
#  10  EMPLOY DATE              149481 non-null  object
#  11  HRLY RATE                149481 non-null  float64
#  12  HRS PER WK               149481 non-null  float64
#  13  MONTHLY                  149481 non-null  float64
#  14  ANNUAL                   149481 non-null  float64
#  15  STATE NUMBER             149481 non-null  int64
#  16  duplicated               143 non-null     object
#  17  multiple_full_time_jobs  14 non-null      float64
#  18  combined_multiple_jobs   97 non-null      object
#  19  summed_annual_salary     16 non-null      float64
#  20  hide_from_search         16 non-null      object
# dtypes: float64(6), int64(2), object(13)
# memory usage: 23.9+ MB

# %%
df.describe()
# Out:
#               AGENCY      HRLY RATE     HRS PER WK        MONTHLY  \
# count  149481.000000  149481.000000  149481.000000  149481.000000
# mean      545.736288       0.346488      39.714918    4226.184248
# std       139.057691       4.211485       2.323855    2093.111691
# min       101.000000       0.000000       1.000000      50.000000
# 25%       529.000000       0.000000      40.000000    3019.840000
# 50%       530.000000       0.000000      40.000000    3720.170000
# 75%       696.000000       0.000000      40.000000    4865.810000
# max       930.000000     117.788480      70.000000   46125.000000
#
#               ANNUAL  STATE NUMBER  multiple_full_time_jobs  \
# count  149481.000000  1.494810e+05                     14.0
# mean    50714.210973  5.651930e+05                      1.0
# std     25117.340292  4.786212e+05                      0.0
# min       600.000000  1.000000e+00                      1.0
# 25%     36238.080000  1.133340e+05                      1.0
# 50%     44642.040000  3.463730e+05                      1.0
# 75%     58389.720000  1.100500e+06                      1.0
# max    553500.000000  1.271604e+06                      1.0
#
#        summed_annual_salary
# count             16.000000
# mean           74303.955000
# std            51925.944282
# min            18000.000000
# 25%            32962.500000
# 50%            48063.300000
# 75%           123751.770000
# max           171383.400000

# %%
df.describe(include="object").T
# Out:
#                          count unique  \
# AGENCY NAME             149481    113
# LAST NAME               149481  38675
# FIRST NAME              149481  23559
# MI                      149481     27
# CLASS CODE              149481   1481
# CLASS TITLE             149481   1422
# ETHNICITY               149481      6
# GENDER                  149481      2
# STATUS                  149481     11
# EMPLOY DATE             149481   6295
# duplicated                 143      1
# combined_multiple_jobs      97      1
# hide_from_search            16      1
#
#                                                                       top  \
# AGENCY NAME             HEALTH AND HUMAN SERVICES COMMISSION          ...
# LAST NAME                                  SMITH
# FIRST NAME                                 MICHAEL
# MI
# CLASS CODE                                                       4504
# CLASS TITLE             CORREC  OFFICER IV                            ...
# ETHNICITY                                                 WHITE
# GENDER                                                    FEMALE
# STATUS                           CRF - CLASSIFIED REGULAR FULL-TIME
# EMPLOY DATE                                                      09/01/17
# duplicated                                                           True
# combined_multiple_jobs                                               True
# hide_from_search                                                     True
#
#                           freq
# AGENCY NAME              36667
# LAST NAME                 1243
# FIRST NAME                1843
# MI                       38408
# CLASS CODE                9267
# CLASS TITLE               9267
# ETHNICITY                67142
# GENDER                   85328
# STATUS                  142502
# EMPLOY DATE              12359
# duplicated                 143
# combined_multiple_jobs      97
# hide_from_search            16

# %% [markdown]
# ## Insights :
#
# 1) The dataset is salary dataset for positions at all 113 agencies in the Texas state government with **149481 datapoints having 21 features** including target variable.
#
# 2) Dataset having both **numerical(8) as well as categorical values(13)** with some null values is there in "duplicated","multiple_full_time_jobs","combined_multiple_jobs", "summed_annual_salary", "hide_from_search" columns.
#
# 3) The maximum salary earned by employee per year is **553500**, where as minimum is 600.
#
# 4) The maximum working hour per week per employee is **70** hours, where as minimum is **1** hour.
#
# 5) The unique number assigned to a business or organization by the state where the business operates, and is used for filing taxes and hiring employees.
#
# 6) Datataset given **monthly as well as annual sallary of individual**. We select monthly salary as one of our feature variable and **annual salary as our target variable**
#
# 7) The standard deviation for "multiple full time jobs" column is 0, hence their is no variance in the data, we can drop that particular column in our data preprocessing step.

# %%
df.columns
# Out:
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL', 'STATE NUMBER',
#        'duplicated', 'multiple_full_time_jobs', 'combined_multiple_jobs',
#        'summed_annual_salary', 'hide_from_search'],
#       dtype='object')

# %%
df.isnull().sum()/len(df)*100
# Out:
# AGENCY                      0.000000
# AGENCY NAME                 0.000000
# LAST NAME                   0.000000
# FIRST NAME                  0.000000
# MI                          0.000000
# CLASS CODE                  0.000000
# CLASS TITLE                 0.000000
# ETHNICITY                   0.000000
# GENDER                      0.000000
# STATUS                      0.000000
# EMPLOY DATE                 0.000000
# HRLY RATE                   0.000000
# HRS PER WK                  0.000000
# MONTHLY                     0.000000
# ANNUAL                      0.000000
# STATE NUMBER                0.000000
# duplicated                 99.904336
# multiple_full_time_jobs    99.990634
# combined_multiple_jobs     99.935109
# summed_annual_salary       99.989296
# hide_from_search           99.989296
# dtype: float64

# %% [markdown]
# There are few 99% null deatures, so we need to remove them from the dataset, as they're not useful

# %%
df = df.drop(['duplicated', 'multiple_full_time_jobs', 'combined_multiple_jobs',
       'summed_annual_salary', 'hide_from_search'], axis = 1)

# %%
df.isnull().sum()/len(df)
# Out:
# AGENCY          0.0
# AGENCY NAME     0.0
# LAST NAME       0.0
# FIRST NAME      0.0
# MI              0.0
# CLASS CODE      0.0
# CLASS TITLE     0.0
# ETHNICITY       0.0
# GENDER          0.0
# STATUS          0.0
# EMPLOY DATE     0.0
# HRLY RATE       0.0
# HRS PER WK      0.0
# MONTHLY         0.0
# ANNUAL          0.0
# STATE NUMBER    0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %% [markdown]
# ## Scatterplot for each continious variable vs target

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is your DataFrame with columns 'MONTHLY', 'ANNUAL', and 'HRLY RATE'

# Creating subplots for scatterplots
fig, axs = plt.subplots(1, 2, figsize=(15, 6))  # 1 row, 2 columns

# Scatterplot 1 - Upper Left
axs[0].scatter(df['MONTHLY'], df['ANNUAL'])
axs[0].set_title('Monthly vs Annual')
axs[0].set_xlabel('Monthly')
axs[0].set_ylabel('Annual')

# Scatterplot 2 - Upper Right
axs[1].scatter(df['HRLY RATE'], df['ANNUAL'])
axs[1].set_title('Hourly Rate vs Annual')
axs[1].set_xlabel('Hourly Rate')
axs[1].set_ylabel('Annual')

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# ### HRLY_RATE and MONTHLY is having linear trend with annual.
# #### Annual and mothly are highly correlated

# %%
sns.scatterplot(x = 'HRS PER WK', y = 'ANNUAL', data = df)
plt.title('Annual vs Hours per week')
# Out:
# Text(0.5, 1.0, 'Annual vs Hours per week')

# %% [markdown]
# ## The people who are working **30-40 HRS_PER_WEEK** are getting higher salaries compared to others.

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(data = df)

# %% [markdown]
# ## Count plot of Gender and ethnicity

# %%
# Create a single figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(8, 4))

# Plot the countplot for 'ETHNICITY' in the first subplot
sns.countplot(x='ETHNICITY', data=df, ax=axs[0])

# Adjust x-axis ticks for 'ETHNICITY' subplot
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=45, ha='right')  # Adjust rotation as needed

# Plot the countplot for 'GENDER' in the second subplot
sns.countplot(x='GENDER', data=df, ax=axs[1])

# Adjust x-axis ticks for 'GENDER' subplot
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=45, ha='right')  # Adjust rotation as needed

# Adjust layout for better spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
df['ETHNICITY'].value_counts()
# Out:
# ETHNICITY
# WHITE              67142
# HISPANIC           40585
# BLACK              35853
# ASIAN               4268
# OTHER                921
# AM INDIAN            712
# Name: count, dtype: int64

# %%
df['GENDER'].value_counts()
# Out:
# GENDER
# FEMALE             85328
# MALE               64153
# Name: count, dtype: int64

# %% [markdown]
# ## Status value counts and count plot

# %%
df['STATUS'].value_counts()
# Out:
# STATUS
# CRF - CLASSIFIED REGULAR FULL-TIME          142502
# URF - UNCLASSIFIED REGULAR FULL-TIME          2363
# CRP - CLASSIFIED REGULAR PART-TIME            1531
# CTF - CLASSIFIED TEMPORARY FULL-TIME          1096
# URP - UNCLASSIFIED REGULAR PART-TIME           950
# ERF - EXEMPT REGULAR FULL-TIME                 923
# CTP - CLASSIFIED TEMPORARY PART-TIME            81
# UTP - UNCLASSIFIED TEMPORARY PART-TIME          21
# UTF - UNCLASSIFIED TEMPORARY FULL-TIME          12
# ERP - EXEMPT REGULAR PART-TIME                   1
# CTP - CLASSIFIED TEMPORARY FULL-TIME             1
# Name: count, dtype: int64

# %%
status_counts = df['STATUS'].value_counts()
status_visul = pd.DataFrame(status_counts)
status_visual = pd.DataFrame({'Status': status_counts.index, 'Count': status_counts.values})

# Plotting using Seaborn's barplot
plt.figure(figsize=(10, 4))
sns.barplot(x='Count', y='Status', data=status_visual)
plt.title('Count of Status Categories')
plt.xlabel('Count')
plt.ylabel('Status')
plt.show()

# %%
status_visual
# Out:
#                                       Status   Count
# 0   CRF - CLASSIFIED REGULAR FULL-TIME        142502
# 1   URF - UNCLASSIFIED REGULAR FULL-TIME        2363
# 2   CRP - CLASSIFIED REGULAR PART-TIME          1531
# 3   CTF - CLASSIFIED TEMPORARY FULL-TIME        1096
# 4   URP - UNCLASSIFIED REGULAR PART-TIME         950
# 5   ERF - EXEMPT REGULAR FULL-TIME               923
# 6   CTP - CLASSIFIED TEMPORARY PART-TIME          81
# 7   UTP - UNCLASSIFIED TEMPORARY PART-TIME        21
# 8   UTF - UNCLASSIFIED TEMPORARY FULL-TIME        12
# 9   ERP - EXEMPT REGULAR PART-TIME                 1
# 10  CTP - CLASSIFIED TEMPORARY FULL-TIME           1

# %% [markdown]
# ## Class title value counts

# %%
df['CLASS TITLE'].value_counts()
# Out:
# CLASS TITLE
# CORREC  OFFICER IV                                    9267
# CORREC  OFFICER V                                     7895
# CORREC OFFCR III                                      4718
# TEXAS WORKS ADVISOR II                                3646
# DIRECT SUPPORT PROFESSIONAL I                         3307
#                                                       ...
# CHAIR,PARDONS AND PAROLES                                1
# STATISTICIAN II                                          1
# EX DIRECTOR TDCJ                                         1
# PAYROLL SPECIALIST I                                     1
# DEPUTY DIR/APPS MGR                                      1
# Name: count, Length: 1422, dtype: int64

# %%
df['CLASS TITLE'].nunique()
# Out:
# 1422

# %% [markdown]
# ## Agency name value counts

# %%
df['AGENCY NAME'].value_counts().sort_values(ascending=False)
# Out:
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                  36667
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                  35926
# TEXAS DEPARTMENT OF TRANSPORTATION                    13099
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES          12588
# DEPARTMENT OF PUBLIC SAFETY                           10097
#                                                       ...
# HEALTH PROFESSIONS COUNCIL                                7
# BOARD OF PROFESSIONAL GEOSCIENTISTS                       5
# OFFICE OF STATE PROSECUTING ATTORNEY                      4
# BOARD OF PROFESSIONAL LAND SURVEYING                      4
# TEXAS BEHAVIORAL HEALTH EXECUTIVE COUNCIL                 1
# Name: count, Length: 113, dtype: int64

# %% [markdown]
# ## Top 15 agency value counts

# %%
df['AGENCY'].value_counts()[:15].plot(kind = 'bar');

# %% [markdown]
# # Univariate analysis

# %%
# Create a 2x2 grid of subplots
fig, axis = plt.subplots(2, 2, figsize=(12, 8))

# Plot histograms in each subplot
sns.histplot(x='ANNUAL', data=df, bins=30, ax=axis[0, 0])
sns.histplot(x='MONTHLY', data=df, bins=30, ax=axis[0, 1])
sns.histplot(x='HRLY RATE', data=df, bins=30, ax=axis[1, 0])
sns.histplot(x='HRS PER WK', data=df, bins=30, ax=axis[1, 1])

# Adjusting layout with space between subplots
plt.subplots_adjust(wspace=0.4, hspace=0.4)  # Adjust the values as needed

# Display the plot
plt.show()

# %% [markdown]
# ## Average Annual salary of male and female

# %%
plt.figure(figsize = (8,4))
sns.catplot(x = 'GENDER', y = 'ANNUAL', data = df, kind = 'bar')

# %% [markdown]
# ## Male individuals are getting more salary compared to Female individuals.

# %% [markdown]
# ## Average annual salary by ethnicity wise

# %%
plt.figure(figsize = (8,4))
g = sns.catplot(x = 'ETHNICITY', y = 'ANNUAL', data = df, kind = 'bar', col = 'GENDER')
# Adjust x-axis ticks for each subplot individually
for ax in g.axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
    ax.margins(x=0.01)

# %% [markdown]
# ### Excluding WHITE peoples others are getting less than 300000$ per annum.
#
# ### The highest salary paid to WHITE people is about 500000$ per annum.

# %% [markdown]
# ## Avg Annual salary by Status wise

# %%
g = sns.catplot(x = 'STATUS', y = 'ANNUAL', data = df, col ='GENDER', kind = 'bar')

plt.gcf().subplots_adjust(bottom=0.15)

# Adjust x-axis ticks for each subplot individually
for ax in g.axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
    ax.margins(x=0.01)  # Adjust margins if needed to prevent cutoff

# Set figure size
g.fig.set_size_inches(12, 6)

# Display the plot
plt.show()

# %% [markdown]
# ### The maximum salaries are earned by **UNCLASSIFIED REGULAR FULL-TIME** and **EXEMPT REGULAR FULL-TIME**.

# %% [markdown]
# ## Avg Hours per week by gender and ethnicity wise

# %%
sns.catplot(x = 'GENDER', y = 'HRS PER WK', data = df, col = 'ETHNICITY', kind = 'bar', col_wrap = 3, height = 4)

# %% [markdown]
# ## Avg hourly rate by gender and ethnicity wise

# %%
sns.catplot(x = 'GENDER', y = 'HRLY RATE', data = df, col = 'ETHNICITY', kind = 'bar', col_wrap = 3, height = 4)

# %% [markdown]
# ## **Insights from Univariate analysis**
#
# More employees belongs to WHITE people.
#
# More employees are FEMALE individuals.
#
# HRS_PER_WEEK is having normal distribution.
#
# HRLY_RATE and MONTHLY is having left skewed distribution.
#
# The majority of an employee is less than 10000 dollars per month.
#
# The majority of employees works in CLASSIFIED_REGULAR_FULL_TIME.
#
# The majority of employee working in HEALTH AND HUMAN SERVICES COMMISSION that is about 36667 and TEXAS DEPARTMENT OF CRIMINAL JUSTICE is being in second place having 35926.
#
# The majority no. of employees earn on a range of 0-8 dollars per hour.
#
# The majority no.of employees work on an avearge of 40 hours per week.

# %%
df.columns
# Out:
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL', 'STATE NUMBER'],
#       dtype='object')

# %%
df['AGENCY NAME'].value_counts()
# Out:
# AGENCY NAME
# HEALTH AND HUMAN SERVICES COMMISSION                  36667
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                  35926
# TEXAS DEPARTMENT OF TRANSPORTATION                    13099
# DEPARTMENT OF FAMILY AND PROTECTIVE SERVICES          12588
# DEPARTMENT OF PUBLIC SAFETY                           10097
#                                                       ...
# HEALTH PROFESSIONS COUNCIL                                7
# BOARD OF PROFESSIONAL GEOSCIENTISTS                       5
# OFFICE OF STATE PROSECUTING ATTORNEY                      4
# BOARD OF PROFESSIONAL LAND SURVEYING                      4
# TEXAS BEHAVIORAL HEALTH EXECUTIVE COUNCIL                 1
# Name: count, Length: 113, dtype: int64

# %% [markdown]
# ## Top 5 agency names and their salaries

# %%
# Get the top 5 categories based on value counts
top_5_agencies = df['AGENCY NAME'].value_counts().head(5).index.tolist()

# Filter the DataFrame for the top 5 categories
df_top_5 = df[df['AGENCY NAME'].isin(top_5_agencies)]

# %%
df.groupby('AGENCY NAME')['ANNUAL'].mean().sort_values(ascending = False)
# Out:
# AGENCY NAME
# COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECTION     138298.202091
# TEXAS BEHAVIORAL HEALTH EXECUTIVE COUNCIL             120000.000000
# TREASURY SAFEKEEPING TRUST COMPANY                    117943.637746
# CANCER PREVENTION AND RESEARCH INSTITUTE OF TEXAS     117206.127273
# FOURTEENTH COURT OF APPEALS DISTRICT                  112452.993000
#                                                           ...
# SCHOOL FOR THE BLIND AND VISUALLY IMPAIRED             42852.887368
# HEALTH AND HUMAN SERVICES COMMISSION                   41851.890192
# TEXAS DEPARTMENT OF CRIMINAL JUSTICE                   41157.350070
# HOUSE OF REPRESENTATIVES                               40884.925122
# STATE PRESERVATION BOARD                               40858.390588
# Name: ANNUAL, Length: 113, dtype: float64

# %%
mean_salary_by_agency = df.groupby('AGENCY NAME')['ANNUAL'].mean().sort_values(ascending=False)
top_5_agencies = mean_salary_by_agency.head(5).index.tolist()
df_top_5 = df[df['AGENCY NAME'].isin(top_5_agencies)]

# %%
g = sns.catplot(x = 'AGENCY NAME', y = 'ANNUAL', data = df_top_5, col ='GENDER', kind = 'bar')
for ax in g.axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
    ax.margins(x=0.01)  # Adjust margins if needed to prevent cutoff

# Set figure size
g.fig.set_size_inches(12, 6)

# Display the plot
plt.show()

# %% [markdown]
# ## **TASK 3**
# Who are the outliers in the salaries?

# %% [markdown]
# # Analyzing outliers

# %%
df.columns
# Out:
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL', 'STATE NUMBER'],
#       dtype='object')

# %% [markdown]
# ## Finding outliers in the salary

# %%
df['ANNUAL'].describe()
# Out:
# count    149481.000000
# mean      50714.210973
# std       25117.340292
# min         600.000000
# 25%       36238.080000
# 50%       44642.040000
# 75%       58389.720000
# max      553500.000000
# Name: ANNUAL, dtype: float64

# %%
Outlier_in_salaries = df[(df['ANNUAL']>58389) | (df['ANNUAL']<36238)]['CLASS TITLE'].unique()
(Outlier_in_salaries.tolist())
# Out:
# ['JUDGE, RETIRED                                    ',
#  'GENERAL COUNSEL IV                                ',
#  'DIRECTOR IV                                       ',
#  'CONTRACT SPEC IV                                  ',
#  'INSPECTOR II                                      ',
#  'PROGRAM SPECIALIST V                              ',
#  'PROGRAM SPECIALIST VI                             ',
#  'VEHICLE DRIVER II                                 ',
#  'RESIDENT SPECIALIST II                            ',
#  'RESIDENT SPECIALIST III                           ',
#  'LIBRARY ASST III                                  ',
#  'ADMINISTRATIVE ASST III                           ',
#  'ADMINISTRATIVE ASST II                            ',
#  'VEHICLE DRIVER III                                ',
#  'NURSE II                                          ',
#  'HOURLY/SUBSTITUTES                                ',
#  'RESIDENT SPECIALIST I                             ',
#  'SUBSTITUTE WORKERS                                ',
#  'LEGISLATIVE PROFESSIONAL                          ',
#  'LEG. OFFICIAL/ADMINISTRATOR                       ',
#  'LEG. SERVICE/MAINTENANCE                          ',
#  'ANALYST                                           ',
#  'ELECTED OFFICIALS STAFF                           ',
#  'COMMITTEE DIRECTOR                                ',
#  'PLANNER V                                         ',
#  'CONTRACT ADMIN MANAGER I                          ',
#  'PORTFOLIO PROJECT MANAGER I                       ',
#  'PROGRAM SPECIALIST II                             ',
#  'DIRECTOR II                                       ',
#  'MGR I                                             ',
#  'PROGRAM SUPERVISOR VII                            ',
#  'PROGRAMMER III                                    ',
#  'PROJECT MANAGER IV                                ',
#  'ADMINISTRATIVE ASST I                             ',
#  'MGR III                                           ',
#  'RISK MGMT SPEC I                                  ',
#  'DIRECTOR VI                                       ',
#  'SYSTEMS ADMINISTRATOR III                         ',
#  'MGR V                                             ',
#  'DIRECTOR V                                        ',
#  'PROGRAMMER IV                                     ',
#  'ARCHITECT IV                                      ',
#  'CUSTOMER SERVICE REP II                           ',
#  'CUSTOMER SERVICE REP I                            ',
#  'MAINTENANCE SUPERVISOR IV                         ',
#  'PROG IV                                           ',
#  'LEG COUN I                                        ',
#  'MEDIA & EDUCATION TEAM LEAD                       ',
#  'SPECIAL COUNSEL                                   ',
#  'RECEPTIONIST                                      ',
#  'PROG III                                          ',
#  'SECTION COORDINATOR                               ',
#  'MGR, COMPUTER SUPPORT CENTER                      ',
#  'EXEC DIRECTOR                                     ',
#  'DEPUTY DIR, LEGAL                                 ',
#  'LEG ED IV                                         ',
#  'ADP OPERATOR II                                   ',
#  'PROGRAMMER V                                      ',
#  'SYS PROG II                                       ',
#  'PRINT SHOP MANAGER                                ',
#  'LEG COUN IV                                       ',
#  'DOC DEL/FILING ASST                               ',
#  'CHIEF REVIEWER                                    ',
#  'ASSISTANT CHIEF REVIEWER                          ',
#  'SYSTEM PROGRAMMER I                               ',
#  'SR LEG COUNSEL                                    ',
#  'SENIOR PARALEGAL                                  ',
#  'ASST CHIEF EDITOR                                 ',
#  'DEPUTY DIRECTOR                                   ',
#  'SENIOR TRAINER                                    ',
#  'ADMIN ASST                                        ',
#  'LEG OFFICE CONSULTANT IV                          ',
#  'SR WRITING RVWR/EDITOR                            ',
#  'DEP DIR/SPEC PROJECTS                             ',
#  'SYSTEM ADMINISTRATOR III                          ',
#  'LEG COUN II                                       ',
#  'QUALITY ASSURANCE ANALYST II                      ',
#  'PROG AN III                                       ',
#  'INFRASTRUCTURE SPECIALIST III                     ',
#  'LEG OFFICIAL/ADMINISTRATOR                        ',
#  'SYSTEM ADMINISTRATOR II                           ',
#  'DIR, INFO SYSTEMS                                 ',
#  'SYSTEM ANALYST V                                  ',
#  'IT SUPPORT CENTER TEAM LEAD                       ',
#  'LEG ED III                                        ',
#  'MARS TECHNOLOGH PROJECT LEAD                      ',
#  'ADVISORY DEPUTY DIRECTOR                          ',
#  'SPECIAL RESEARCH ASSOC                            ',
#  'SHIFT COORDINATOR                                 ',
#  'KNOWLEDGE & DATABASE MGMT SPEC                    ',
#  'LEG COUN V                                        ',
#  'TEAM LDR SPCZD CLIENT SUPP                        ',
#  'DATABASE ADMINISTRATOR I                          ',
#  'PROJECT LEADER                                    ',
#  'SYSTEMS ANALYST V/PM OFFICER                      ',
#  'SYS PROG IV                                       ',
#  'SENIOR WRITING ASSOCIATE                          ',
#  'ADP OPER III                                      ',
#  'SECTION MANAGER                                   ',
#  'PROG AN IV                                        ',
#  'TEAM LEADER LEG SUPP TEAM                         ',
#  'POLICY ASSISTANT                                  ',
#  'SYSTEM ADMINISTRATOR I                            ',
#  'COMP AND BENEFITS SPEC                            ',
#  'PRINT SPECIALIST II                               ',
#  'SR HR GEN/WELLNESS COORD                          ',
#  'GENERAL COUNSEL                                   ',
#  'TEAM LEADER TLC SUPP TEAM                         ',
#  'ASSISTANT PROJECT LEADER                          ',
#  'INFRA SPEC IV                                     ',
#  'SYS PROG III                                      ',
#  'PROGRAMMER VI                                     ',
#  'GRAPHICS COORDINATRO                              ',
#  'FINAL REVIEWER                                    ',
#  'MGR, FAC & ASSUR SVCS                             ',
#  'LEG COUN III                                      ',
#  'SR ACCOUNTANT                                     ',
#  'PROG AN II                                        ',
#  'LEG OFFICE CONSULTANT III                         ',
#  'DIR, LEGAL DIV                                    ',
#  'ELECTIONS & SPEC PROJECTS LEAD                    ',
#  'SOCIAL SCIENCE STATISTICAN                        ',
#  'RES ASSOC                                         ',
#  'MGR, HUMAN RES                                    ',
#  'UX DESIGNER/PROJECT MANAGER                       ',
#  'NETWORK ADMINISTRATOR III                         ',
#  'CONTRACT & PURCH PROG MGR                         ',
#  'DATABASE ADMINISTRATOR II                         ',
#  'MGR,INFRASTRUCTURE AND OPS                        ',
#  'TECHNICAL SUPPORT SPECIALIST                      ',
#  'NETWORK ADMINISTRATOR IV                          ',
#  'CHIEF FINANCIAL OFFICER                           ',
#  'FACILITIES COORDINATOR                            ',
#  'MGR, PROOFREADING                                 ',
#  'SEC COORDINATOR, DATA TRNSCRPT                    ',
#  'DEPUTY DIR/APPS MGR                               ',
#  'ASST EXEC DIRECTOR                                ',
#  'EDUCATION TEAM LEAD                               ',
#  'WEB & E LEARNING SPECIALIST                       ',
#  'TEAM LEADER OFF SUPPORT TEAM                      ',
#  'ADMIN MGR, LEGAL                                  ',
#  'CONTENT COORDINATOR                               ',
#  'DIR, DOC PROD                                     ',
#  'SPECIAL PROJECTS MGR                              ',
#  'PROGRAMMER VII                                    ',
#  'CHIEF LEGAL EDITOR                                ',
#  'NETWORK ADMINISTRATOR II                          ',
#  'SENIOR PROOFREADER                                ',
#  'MANAGER PROC/DEL                                  ',
#  'DIR, RESEARCH                                     ',
#  'LIBRARY ASSISTANT II                              ',
#  'DIRECTOR                                          ',
#  'ADMIN ASSNT II                                    ',
#  'LIBRARIAN IV                                      ',
#  'ADMIN TECHN III                                   ',
#  'INFO SPEC IV                                      ',
#  'PURCHASER IV                                      ',
#  'DIRECTOR III                                      ',
#  'JUSTICE                                           ',
#  'ATTORNEY IV                                       ',
#  'ATTORNEY III                                      ',
#  'DIRECTOR I                                        ',
#  'EXECUTIVE ASST II                                 ',
#  'CLERK OF THE COURT                                ',
#  'CHIEF JUSTICE                                     ',
#  'GENERAL COUNSEL III                               ',
#  'CHIEF DEPUTY CLERK                                ',
#  'PROGRAM SPECIALIST III                            ',
#  'ATTORNEY V                                        ',
#  'ACCOUNTANT V                                      ',
#  'JUDGE                                             ',
#  'PRESIDING JUDGE                                   ',
#  'NETWORK SPEC III                                  ',
#  'FINANCIAL EXAM VII                                ',
#  'LEGAL ASSISTANT IV                                ',
#  'ASSOCIATE JUDGE                                   ',
#  'AUDITOR IV                                        ',
#  'PROGRAM SPECIALIST IV                             ',
#  'AUDITOR V                                         ',
#  'NETWORK SPEC V                                    ',
#  'DATA BASE ADMINISTRATOR IV                        ',
#  'WEB ADMINISTRATOR V                               ',
#  'ACCOUNTANT VI                                     ',
#  'INTERPRETER III                                   ',
#  'DATA BASE ADMINISTRATOR III                       ',
#  'MGR II                                            ',
#  'DATA ANALYST V                                    ',
#  'BUDGET ANALYST V                                  ',
#  'GENERAL COUNSEL II                                ',
#  'PROJECT MANAGER III                               ',
#  'BUDGET ANALYST IV                                 ',
#  'RESEARCH SPEC IV                                  ',
#  'PROGRAM SPECIALIST VII                            ',
#  'SYSTEMS ANALYST IV                                ',
#  'INFO TECH SECURITY ANALYST I                      ',
#  'GENERAL COUNSEL V                                 ',
#  'WEB ADMINISTRATOR IV                              ',
#  'PAYROLL SPECIALIST IV                             ',
#  'HR SPEC IV                                        ',
#  'COURT COORDINATOR                                 ',
#  'ADMINSTRATIVE DIRECTOR                            ',
#  'MANAGEMENT ANALYST III                            ',
#  'EXECUTIVE ASST III                                ',
#  'SYSTEMS ANALYST VII                               ',
#  'STATE PROSECUTING ATTORNEY                        ',
#  'ATTORNEY II                                       ',
#  'ATTORNEY I                                        ',
#  'INVESTIGATOR IV                                   ',
#  'EXECUTIVE DIRECTOR                                ',
#  'NETWORK SPEC IV                                   ',
#  'DPTY CLERK II                                     ',
#  'LEGAL ASSISTANT III                               ',
#  'CUSTODIAN III                                     ',
#  'ACCOUNTANT IV                                     ',
#  'DPTY CLERK III                                    ',
#  'BUDGET ANALYST III                                ',
#  'DPTY CLERK I                                      ',
#  'LEGAL SECRETARY IV                                ',
#  'SAFETY OFFCR IV                                   ',
#  'SECURITY OFFICER IV                               ',
#  'STAFF SRVCS OFFCR III                             ',
#  'STAFF SRVCS OFFCR IV                              ',
#  'DISTRICT JUDGE, ACTIVE                            ',
#  'CRIMINAL DISTRICT ATTORNEY                        ',
#  'RETIRED COUNTY COURT JUDGE                        ',
#  'CRIMINAL DISTRICT ATTORNEYCNP                     ',
#  'DISTRICT JUDGE, FORMER                            ',
#  'DISTRICT ATTORNEY                                 ',
#  'MGR IV                                            ',
#  'INVESTIGATOR VII                                  ',
#  'DIRECTOR, STATE LAW LIBRARY                       ',
#  'SYSTEMS SUPPORT SPECIALIST III                    ',
#  'PROGRAM SUPERVISOR VI                             ',
#  'DIRECTOR VII                                      ',
#  'PLANNER IV                                        ',
#  'MARKETING SPECIALIST III                          ',
#  'EXECUTIVE DIRECTOR OSFR                           ',
#  'MARKETING SPECIALIST IV                           ',
#  'GOVERNOR                                          ',
#  'EDITOR III                                        ',
#  "GOVERNOR'S ADVISOR III                            ",
#  "GOVERNOR'S ADVISOR V                              ",
#  'COMPLIANCE ANALYST IV                             ',
#  'PROPERTY MGR II                                   ',
#  'INFO SPEC V                                       ',
#  'PURCHASER V                                       ',
#  "GOVERNOR'S ADVISOR IV                             ",
#  'SYSTEMS ANALYST VI                                ',
#  'ACCOUNTANT VII                                    ',
#  'DEPUTY DIRECTOR III                               ',
#  'HR SPEC VI                                        ',
#  'CONTRACT SPEC V                                   ',
#  'CUSTODIAL MGR I                                   ',
#  'INFO SPEC III                                     ',
#  'DEPUTY DIRECTOR II                                ',
#  'AUDITOR II                                        ',
#  'DEPUTY DIRECTOR I                                 ',
#  'INFO SPEC I                                       ',
#  "LIEUTENANT, TEXAS AG'S OFFICE                     ",
#  'ASST ATTORNEY GENERAL I                           ',
#  'CHILD SUPPORT OFFICER V                           ',
#  'ASST ATTORNEY GENERAL V                           ',
#  'ASST ATTORNEY GENERAL VI                          ',
#  'TRAINING SPEC IV                                  ',
#  'PROGRAM SUPERVISOR III                            ',
#  'BUSINESS CONTINUITY COORD II                      ',
#  'CHILD SUPPORT TECHN II                            ',
#  "SERGEANT, TEXAS AG'S OFFICE                       ",
#  'ASST ATTORNEY GENERAL II                          ',
#  'INVESTIGATOR VI                                   ',
#  'SYSTEMS ANALYST V                                 ',
#  'ASST ATTORNEY GENERAL III                         ',
#  'ASST ATTORNEY GENERAL IV                          ',
#  "CAPTAIN, TEXAS AG'S OFFICE                        ",
#  'ASST ATTORNEY GENERAL VII                         ',
#  'INVESTIGATOR V                                    ',
#  'ADMINISTRATIVE ASST V                             ',
#  "MAJOR, TEXAS AG'S OFFICE                          ",
#  'SYSTEMS ADMINISTRATOR V                           ',
#  'PROJECT MANAGER II                                ',
#  'DEPUTY ATTORNEY GENERAL                           ',
#  'PROJECT MANAGER I                                 ',
#  'TRAINING SPEC V                                   ',
#  'INFORMATION SECURITY OFFICER                      ',
#  'NETWORK SPECIALIST VI                             ',
#  'LEGAL ASSISTANT V                                 ',
#  'INFO TECH SECURITY ANALYST II                     ',
#  'SYSTEMS ADMINISTRATOR IV                          ',
#  'GRANT COORDINATOR II                              ',
#  'CLERK III                                         ',
#  'BUSINESS ANALYST III                              ',
#  'PROGRAM SUPERVISOR V                              ',
#  'INFO TECH SECURITY ANALYST III                    ',
#  'HR SPEC I                                         ',
#  'ACCOUNTANT I                                      ',
#  'LEGAL SECRETARY V                                 ',
#  'INVENTORY & STORE SPEC  II                        ',
#  'REIMBURSEMENT OFFICER IV                          ',
#  'SYSTEMS SUPPORT SPECIALIST IV                     ',
#  'PROGRAMMER II                                     ',
#  'QUALITY ASSURANCE SPEC III                        ',
#  'SECURITY OFFICER II                               ',
#  'LEGAL SECRETARY I                                 ',
#  'ECONOMIST IV                                      ',
#  'NETWORK SPEC II                                   ',
#  'CHIEF INFO SECURITY OFFICER                       ',
#  'SYSTEMS ANALYST III                               ',
#  'CHILD SUPPORT OFFCR II                            ',
#  'PROGRAM SUPERVISOR IV                             ',
#  'TRAINING SPEC VI                                  ',
#  'CONTRACT ADMIN MANAGER II                         ',
#  'SYSTEMS ANALYST II                                ',
#  'WEB ADMINISTRATOR III                             ',
#  'CONTRACT SPEC III                                 ',
#  'CREATIVE MEDIA DESIGNER II                        ',
#  'FIRST ASST ATTORNEY GENERAL                       ',
#  'PROPERTY MGR III                                  ',
#  'QUALITY ASSURANCE SPEC II                         ',
#  'SYSTEMS ADMINISTRATOR II                          ',
#  'HR SPEC V                                         ',
#  'MANAGEMENT ANALYST IV                             ',
#  'ATTORNEY GENERAL                                  ',
#  'CUSTOMER SERVICE REP III                          ',
#  'TELECOMMUNICATIONS SPEC IV                        ',
#  'QUALITY ASSURANCE SPEC IV                         ',
#  'AUDITOR III                                       ',
#  'SECURITY OFFICER III                              ',
#  'ECONOMIST II                                      ',
#  'FINANCIAL ANALYST IV                              ',
#  'CHILD SUPPORT OFFCR III                           ',
#  'BUSINESS ANALYST IV                               ',
#  'TAX AUDITOR III                                   ',
#  'TAX AUDITOR SUPERVISOR                            ',
#  'TAX AUDITOR II                                    ',
#  'TAX ANALYST IV                                    ',
#  'TAX AUDITOR IV                                    ',
#  'APPRAISER IV                                      ',
#  'ACCTS EXAM V                                      ',
#  'MANAGEMENT ANALYST V                              ',
#  'TAX AUDITOR MANAGER                               ',
#  'TAX AUDITOR V                                     ',
#  'CYBERSECURITY ANALYST I                           ',
#  'ADMINISTRATIVE ASST IV                            ',
#  'ACCOUNTANT III                                    ',
#  'ACCTS EXAM IV                                     ',
#  'GOVT RELATIONS SPECIALIST I                       ',
#  'APPRAISER II                                      ',
#  'APPN CONTROL OFFICER IV                           ',
#  'ACCTS EXAM II                                     ',
#  'TAX AUDITOR VI                                    ',
#  'TAXPYR COMPLIANCE OFFCR V                         ',
#  'TAX AUDITOR I                                     ',
#  'CYBERSECURITY ANALYST II                          ',
#  'TECHNICAL WRITER III                              ',
#  'CHIEF CYBERSECURITY OFFICER                       ',
#  'TAX ANALYST I                                     ',
#  'INFO TECHNOLOGY AUDITOR IV                        ',
#  'APPRAISER III                                     ',
#  'GOVT RELATIONS SPECIALIST II                      ',
#  'DEPUTY COMPTROLLER                                ',
#  'TAX ANALYST II                                    ',
#  'APPN CONTROL OFFICER III                          ',
#  'APPN CONTROL OFFICER II                           ',
#  'DATA ANALYST VI                                   ',
#  'HR SPEC III                                       ',
#  'CREATIVE MEDIA DESIGNER III                       ',
#  'INDEPENDENT AUDIT REVIEWER III                    ',
#  'BUSINESS CONTINUITY COORD I                       ',
#  'GEOGRAPHIC INFO SPEC IV                           ',
#  'CYBERSECURITY ANALYST III                         ',
#  'INFO TECH AUDITOR I                               ',
#  'DATA ANALYST IV                                   ',
#  'ACCTS EXAM III                                    ',
#  'MANAGER VI                                        ',
#  'COMPTROLLER OF PUBLIC ACCOUNTS                    ',
#  'DATA BASE ADMINISTRATOR V                         ',
#  'STAFF SRVCS OFFCR II                              ',
#  'PRIVACY ANALYST III                               ',
#  'COMPUTER OPERATIONS SPEC V                        ',
#  'TAX ANALYST III                                   ',
#  'RESEARCH SPEC I                                   ',
#  'FINANCIAL ANALYST III                             ',
#  'INFO TECH AUDITOR III                             ',
#  'PURCHASER VI                                      ',
#  'CREATIVE MEDIA DESIGNER IV                        ',
#  'DATA ANALYST III                                  ',
#  'MULTIMEDIA TECHNICIAN I                           ',
#  'MULTIMEDIA TECHNICIAN II                          ',
#  'LIBRARY ASST I                                    ',
#  'CLERK I                                           ',
#  'MAINTENANCE SPECIALIST I                          ',
#  'LIBRARY ASST II                                   ',
#  'DOCUMENT SERVICES TECH III                        ',
#  'INVENTORY & STORE SPEC I                          ',
#  'DOCUMENT SERVICES TECH I                          ',
#  'DOCUMENT SERVICES TECH II                         ',
#  'DIRECTOR, LIBRARIAN                               ',
#  'PURCHASER I                                       ',
#  'LICENSE AND PERMIT SPEC III                       ',
#  'SECRETARY OF STATE                                ',
#  'ENGINEER V                                        ',
#  'ENGINEERING SPECIALIST IV                         ',
#  'CYBERSECURITY OFFICER                             ',
#  'EDUCATION SPECIALIST V                            ',
#  'CHIEF DATA OFFICER                                ',
#  'WEB ADMINISTRATOR II                              ',
#  'TELECOMMUNICATIONS SPEC II                        ',
#  'MANAGEMENT ANALYST II                             ',
#  'ENGINEER II                                       ',
#  'WORKFORCE DEV SPECIALIST II                       ',
#  'WORKFORCE DEV SPECIALIST I                        ',
#  'UNEMPL INSUR CLAIMS EXAM II                       ',
#  'ACCTS EXAM I                                      ',
#  'VOC REHAB CNSLR IV                                ',
#  'UNEMPL INSUR CLAIMS EXAM III                      ',
#  'HUMAN SERVICES TECHNICIAN III                     ',
#  'COMMISSIONER, WORKFORCE COMM.                     ',
#  'INVESTIGATOR II                                   ',
#  'WORKFORCE DEV SPECIALIST III                      ',
#  'CLERK II                                          ',
#  'H/SRVC SPEC I                                     ',
#  'INVESTIGATOR I                                    ',
#  'H/SRVC SPEC IV                                    ',
#  'UNEMPL INSUR CLAIMS EXAM I                        ',
#  'WORKFORCE DEV SPECIALIST IV                       ',
#  'H/SRVC SPEC III                                   ',
#  'HR ASST                                           ',
#  'TECH WRITER II                                    ',
#  'VEHICLE DRIVER I                                  ',
#  'H/SRVC SPEC VI                                    ',
#  'VOC REHAB CNSLR III                               ',
#  'HEARINGS OFFICER III                              ',
#  'HEARINGS OFFICER I                                ',
#  'SYSTEMS ADMINISTRATOR VI                          ',
#  'PROGRAM SUPERVISOR I                              ',
#  'DATA ARCHITECT I                                  ',
#  'STAFF SRVCS OFFCR V                               ',
#  'DATA OFFICER                                      ',
#  'MAINTENANCE SPECIALIST IV                         ',
#  'MAINTENANCE SPECIALIST III                        ',
#  'GENERAL COUNSEL I                                 ',
#  'CHAIRMAN                                          ',
#  'FOOD SRVC MGR I                                   ',
#  'PROJECT MGT SPECIALIST II                         ',
#  'DATA ANALYST II                                   ',
#  'HVAC MECHANIC III                                 ',
#  'INVENTORY AND STORE SPEC V                        ',
#  'TEACHER AIDE III                                  ',
#  'MAINTENANCE SPECIALIST II                         ',
#  'PROPERTY MANAGER IV                               ',
#  'PSYCHOLOGICAL ASSOCIATE IV                        ',
#  'HEARINGS OFFICER V                                ',
#  'MARKETING SPECIALIST V                            ',
#  'HEARINGS OFFICER II                               ',
#  'UNEMPL INSUR SPEC I                               ',
#  'INVESTIGATOR III                                  ',
#  'CONTRACT TECHN I                                  ',
#  'TRAINING SPEC III                                 ',
#  'INFO TECH AUDITOR II                              ',
#  'TRAINING SPEC II                                  ',
#  'RESEARCH SPEC V                                   ',
#  'ACCOUNTANT II                                     ',
#  'SENIOR DIRECTOR                                   ',
#  'PORTFOLIO MANAGER III                             ',
#  'PROGRAMMER I                                      ',
#  'INVESTMENT ATTORNEY                               ',
#  'INVESTMENT ANALYST III                            ',
#  'INVESTMENT ANALYST V                              ',
#  'INVESTMENT ANALYST II                             ',
#  'CHIEF INVESTMENT OFFICER                          ',
#  'SENIOR MANAGING DIRECTOR                          ',
#  'RETIRE SYS BENEFITS SPEC IV                       ',
#  'PORTFOLIO MANAGER V                               ',
#  'RETIRE SYS BENEFITS SPEC III                      ',
#  'FINANCIAL ANALYST II                              ',
#  'INVESTMENT ANALYST IV                             ',
#  'PORTFOLIO MANAGER IV                              ',
#  'INV MANAGER, LONDON                               ',
#  'EDITOR II                                         ',
#  'BUSINESS ANALYST I                                ',
#  'INV ASSOCIATE, LONDON                             ',
#  'DEPUTY DIRECTOR IV                                ',
#  'SENIOR INVESTMENT ATTORNEY                        ',
#  'RETIRE SYS BENEFITS SPEC I                        ',
#  'INVESTMENT ANALYST I                              ',
#  'ACTUARY IV                                        ',
#  'BUSINESS ANALYST II                               ',
#  'TRADER III                                        ',
#  'CHIEF TRADER I                                    ',
#  'LEAD INVESTMENT ATTORNEY                          ',
#  'DATA ARCHITECT II                                 ',
#  'MANAGING DIRECTOR                                 ',
#  'CHIEF COMPLIANCE OFFICER                          ',
#  'SR INV ASSOCIATE, LONDON                          ',
#  'FINANCIAL EXAM VI                                 ',
#  'PROJECT MANAGER V                                 ',
#  'EDUCATION SPECIALIST IV                           ',
#  'PROGRAM SUPERVISOR II                             ',
#  'INVENTORY & STORE SPEC  III                       ',
#  'LEGAL SECRETARY III                               ',
#  'LOAN SPECIALIST II                                ',
#  'ACCOUNTING TECHNICIAN II                          ',
#  'LOAN SPECIALIST III                               ',
#  'LOAN SPECIALIST IV                                ',
#  'INSPECTOR VI                                      ',
#  'PLANNER II                                        ',
#  'PLANNER III                                       ',
#  'RESEARCH SPEC III                                 ',
#  'EXECUTIVE DIRECTOR, DEPT OF HO                    ',
#  'CHIEF ACTUARY                                     ',
#  'ACTUARY I                                         ',
#  'ADMINISTRATIVE LAW JUDGE III                      ',
#  'ADMINISTRATIVE LAW JUDGE II                       ',
#  'MASTER ADMIN LAW JUDGE I                          ',
#  'ADMINISTRATIVE LAW JUDGE I                        ',
#  'MASTER ADMIN LAW JUDGE II                         ',
#  'CHIEF ADMINISTRATIVE LAW JUDGE                    ',
#  'ENVIRONMENTAL PROTECT SPEC IV                     ',
#  'GEOGRAPHIC INFO SPEC III                          ',
#  'RESIDENT SPECIALIST IV                            ',
#  'DATA BASE ADMINISTRATOR I                         ',
#  'TELECOMMUNICATIONS SPEC III                       ',
#  'MILITARY SPECIALIST III                           ',
#  'CASE MGR II                                       ',
#  'ENVIRONMENTAL PROTECT SPEC V                      ',
#  'NATURAL RESOURCES SPEC V                          ',
#  'INSPECTOR V                                       ',
#  'BEHAVIOR ANALYST I                                ',
#  'NATURAL RESOURCES SPEC III                        ',
#  'RESCUE SPEC III                                   ',
#  'COOK IV                                           ',
#  'MILITARY SPECIALIST IV                            ',
#  'MILITARY SPECIALIST V                             ',
#  'ENVIRONMENTAL PROTECT SPEC III                    ',
#  'BUDGET ANALYST II                                 ',
#  'HISTORIAN III                                     ',
#  'GRANT COORDINATOR III                             ',
#  'MAINTENANCE SUPERVISOR III                        ',
#  'DRAFTING TECHNICIAN II                            ',
#  'ADJUTANT GENERAL                                  ',
#  'ELECTRICIAN III                                   ',
#  'ARCHITECT III                                     ',
#  'NATURAL RESOURCES SPEC IV                         ',
#  'GROUNDSKEEPER III                                 ',
#  'EQUIPMENT OPERATOR I                              ',
#  'RESCUE SPEC II                                    ',
#  'LAND SURVEYOR III                                 ',
#  'GEOGRAPHIC INFO SPEC II                           ',
#  'BEHAVIOR ANALYST II                               ',
#  'ELECTRONICS TECHNICIAN III                        ',
#  'ENGINEERING SPECIALIST III                        ',
#  'VETERANS SERVICES REP III                         ',
#  'EXEC DIRECTOR, VETERANS COMM                      ',
#  'EMERG MGT PROGRAM COORD III                       ',
#  'TROOPER                                           ',
#  'LICENSE AND PERMIT SPEC V                         ',
#  'LICENSE AND PERMIT SPEC II                        ',
#  'SERGEANT, DPS                                     ',
#  'LIEUTENANT, DPS                                   ',
#  'CUSTODIAN II                                      ',
#  'CORPORAL                                          ',
#  'FORENSIC SCIENTIST II                             ',
#  'POLICE COMMUNICATIONS OPER I                      ',
#  'CAPTAIN, DPS                                      ',
#  'ACCOUNTING TECHNICIAN I                           ',
#  'FORENSIC SCIENTIST IV                             ',
#  'FORENSIC SCIENTIST III                            ',
#  'MOTOR VEHICLE TECHNICIAN I                        ',
#  'SYSTEMS SUPPORT SPECIALIST I                      ',
#  'FORENSIC SCIENTIST VI                             ',
#  'HEALTH SPECIALIST V                               ',
#  'PILOT INVESTIGATOR II                             ',
#  'PILOT INVESTIGATOR III                            ',
#  'MAINTENANCE SPECIALIST V                          ',
#  'MAJOR, DPS                                        ',
#  'CRIMINAL INTEL ANALYST III                        ',
#  'INSPECTOR III                                     ',
#  'CRIMINAL INTEL ANALYST II                         ',
#  'HVAC MECHANIC I                                   ',
#  'PUBLIC SAFETY RECORDS TECH III                    ',
#  'CUSTOMER SERVICE REP IV                           ',
#  'FORENSIC SCIENTIST V                              ',
#  'MULTIMEDIA TECHNICIAN III                         ',
#  'COOK III                                          ',
#  'STATISTICIAN III                                  ',
#  'LEGAL SECRETARY II                                ',
#  'PSYCHOLOGIST III                                  ',
#  'CRIMINAL INTEL ANALYST I                          ',
#  'COMMANDER, DPS                                    ',
#  'PUBLIC SAFETY RCDS TECHN II                       ',
#  'DOCUMENT SERVICES TECH IV                         ',
#  'FINGERPRINT ANALYST III                           ',
#  'DIRECTOR, DEPARTMENT OF PUBLIC                    ',
#  'GRANT COORDINATOR IV                              ',
#  'PUBLIC SAFETY RCDS TECHN I                        ',
#  'CRIME ANALYST I                                   ',
#  'SAFETY OFFICER V                                  ',
#  'INVENTORY & STORE SPEC IV                         ',
#  'SYSTEMS SUPPORT SPECIALIST II                     ',
#  'GEOGRAPHIC INFO SPEC V                            ',
#  'FINGERPRINT ANALYST II                            ',
#  'RADIO COMMUNICATIONS TECH II                      ',
#  'PSYCHOLOGIST II                                   ',
#  'TECH WRITER I                                     ',
#  'CUSTODIAL MGR II                                  ',
#  'PUBLIC COUNSEL, OIEC                              ',
#  'CREATIVE MEDIA DESIGNER I                         ',
#  'OMBUDSMAN III                                     ',
#  'BOILER INSPECTOR II                               ',
#  'BOILER INSPECTOR III                              ',
#  'FLEET MANAGER III                                 ',
#  'INSURANCE SPECIALIST I                            ',
#  'SERGEANT, TDI                                     ',
#  'FINANCIAL EXAM III                                ',
#  'CLAIMS EXAMINER I                                 ',
#  'FINANCIAL EXAM V                                  ',
#  'ACTUARY II                                        ',
#  'ENGINEER VI                                       ',
#  'NURSE III                                         ',
#  "COMMISSIONER OF WORKERS' COMP                     ",
#  'RESEARCH AND STATS TECH II                        ',
#  'FINANCIAL EXAM IV                                 ',
#  'CLAIMS EXAMINER II                                ',
#  'BENEFIT REVIEW OFFICER II                         ',
#  'DEPUTY CHIEF INVESTIGATOR, TDI                    ',
#  'ACTUARY V                                         ',
#  'INSURANCE SPECIALIST II                           ',
#  'LICENSE AND PERMIT SPEC I                         ',
#  'ACTUARY III                                       ',
#  'CAPTAIN, TDI                                      ',
#  'BENEFIT REVIEW OFFICER III                        ',
#  'LIEUTENANT, TDI                                   ',
#  'GOVT RELATIONS SPEC III                           ',
#  'ENGINEER IV                                       ',
#  'COMMISSIONER OF INSURANCE, TDI                    ',
#  'GEOSCIENTIST III                                  ',
#  'GEOSCIENTIST IV                                   ',
#  'ENGINEERING SPECIALIST II                         ',
#  'ENGINEERING SPECIALIST V                          ',
#  'ENGINEERING SPECIALIST VI                         ',
#  'COMMISSION                                        ',
#  'INDEPENDENT AUDIT REVIEWER II                     ',
#  'COMPLIANCE ANALYST III                            ',
#  'FINANCIAL ANALYST I                               ',
#  'ENGINEER I                                        ',
#  'TOXICOLOGIST II                                   ',
#  'GEOSCIENTIST V                                    ',
#  'OMBUDSMAN V                                       ',
#  'GEOSCIENTIST II                                   ',
#  'ENGINEER III                                      ',
#  'EXECUTIVE DIRECTOR, TSBPA                         ',
#  'TAXPYR COMPLIANCE OFFCR I                         ',
#  'AGENT                                             ',
#  'TAXPYR COMPLIANCE OFFCR II                        ',
#  'LT, TABC                                          ',
#  'SGT, TABC                                         ',
#  'MAJOR, TABC                                       ',
#  'TAXPYR COMPLIANCE OFFCR III                       ',
#  'CHEMIST II                                        ',
#  'ADMINISTRATOR, TEXAS A B C                        ',
#  'CHEMIST III                                       ',
#  'CAPT, TABC                                        ',
#  'LICENSE AND PERMIT SPEC IV                        ',
#  'COMMISSIONER CREDIT UNION DEPA                    ',
#  'ECONOMIST III                                     ',
#  'COMMISSIONER                                      ',
#  'UTILITY SPECIALIST II                             ',
#  'EMERG MGT PROGRAM COORD IV                        ',
#  'UTILITY SPECIALIST I                              ',
#  'COMMISSION, CHAIR                                 ',
#  'CLAIMS EXAMINER IV                                ',
#  'RISK MGMT SPEC III                                ',
#  'WEB ADMINISTRATOR I                               ',
#  'INSURANCE SPECIALIST III                          ',
#  'NURSE I                                           ',
#  'RISK MGMT SPEC IV                                 ',
#  'PHYSICIAN I                                       ',
#  'INSPECTOR I                                       ',
#  'EXECUTIVE DIRECTOR/SECRETARY                      ',
#  'PHARMACIST I                                      ',
#  'EPIDEMIOLOGIST III                                ',
#  'PHARMACIST II                                     ',
#  'COMPLIANCE ANALYST II                             ',
#  'DIRECT SUPPORT PROF II                            ',
#  'DIRECT SUPPORT PROFESSIONAL I                     ',
#  'TEXAS WORKS ADVISOR II                            ',
#  'PSYCHIATRIST III                                  ',
#  'PSYCHIATRIC NURSING ASST I                        ',
#  'ADV PRACTICE RGD NURSE II                         ',
#  'DIRECT SUPPORT PROF III                           ',
#  'REHAB THERAPY TECHNICIAN III                      ',
#  'DIRECT SUPPORT PROF IV                            ',
#  'PSYCHIATRIC NURSING ASST II                       ',
#  'ADV PRACTICE RGD NURSE I                          ',
#  'PHYSICIAN II                                      ',
#  'TEXAS WORKS ADVISOR I                             ',
#  'REGISTERED THERAPIST V                            ',
#  'COOK II                                           ',
#  'REHAB THERAPY TECHNICIAN IV                       ',
#  'DENTAL HYGIENIST I                                ',
#  'DENTIST III                                       ',
#  'PSYCHIATRIC NURSING ASST IV                       ',
#  'REGISTERED THERAPIST IV                           ',
#  'TEXAS WORKS ADVISOR III                           ',
#  'ORTHOPEDIC EQUIP TECHN I                          ',
#  'CUSTODIAN I                                       ',
#  'REHAB THERAPY TECHNICIAN II                       ',
#  'ADULT CHILD CARE LIC SPEC I                       ',
#  'HEALTH ASSISTANT                                  ',
#  'LAUNDRY/SEWING ROOM WORKER II                     ',
#  'PSYCHOLOGIST I                                    ',
#  'FOOD SERVICE WORKER I                             ',
#  'PSYCHIATRIC NURSING ASST III                      ',
#  'LICENSED VOCATIONAL NURSE I                       ',
#  'AC & BOILER OPER I                                ',
#  'PHARMACY TECHNICIAN II                            ',
#  'LAUNDRY/SEWING ROOM WORKER I                      ',
#  'MAINTENANCE SUPERVISOR I                          ',
#  'PURCHASER II                                      ',
#  'LAUNDRY/SEWING ROOM WORKER III                    ',
#  'SAFETY OFFCR I                                    ',
#  'PHARMACIST III                                    ',
#  'PHYSICIAN ASSISTANT                               ',
#  'LABORATORY TECHNICIAN III                         ',
#  'PHYSICIAN III                                     ',
#  'CONTRACT TECHN III                                ',
#  'DIETETIC & NUTRITION SPEC III                     ',
#  'PHARMACY TECHNICIAN I                             ',
#  'COOK I                                            ',
#  'REIMBURSEMENT OFFICER I                           ',
#  'REHAB THERAPY TECHNICIAN I                        ',
#  'SOCIAL WORKER I                                   ',
#  'PROGRAM SPECIALIST I                              ',
#  'LABORATORY TECHNICIAN I                           ',
#  'ARCHITECT II                                      ',
#  'H/SRVC SPEC II                                    ',
#  'RESIDENT SPECIALIST V                             ',
#  'GROUNDSKEEPER II                                  ',
#  'REHABILITATION TEACHER I                          ',
#  'EDUCATION SPECIALIST III                          ',
#  'PURCHASER III                                     ',
#  'FOOD SERVICE WORKER II                            ',
#  'LICENSED VOCA NURSE TRAINEE                       ',
#  'NURSE IV                                          ',
#  'ADULT PROTECTIVE SVCS SPEC I                      ',
#  'DENTAL ASSISTANT II                               ',
#  'MEDICAL TECHNICIAN II                             ',
#  'RADIOLOGICAL TECHNOLOGIST I                       ',
#  'TRAINING SPEC I                                   ',
#  'GROUNDSKEEPER I                                   ',
#  'HUMAN SERVICES TECHNICIAN II                      ',
#  'PSYCHIATRIST IV                                   ',
#  'ADULT CHILD CARE LIC SPEC V                       ',
#  'MOTOR VEHICLE TECHNICIAN II                       ',
#  'REGISTERED THERAPIST II                           ',
#  'FAMILY SERVICES SPECIALIST I                      ',
#  'ADULT PROTECTIVE SVCS SPEC IV                     ',
#  'HVAC MECHANIC II                                  ',
#  'TRAINING ASST                                     ',
#  'SAFETY OFFCR II                                   ',
#  'REHAB THERAPY TECHNICIAN V                        ',
#  'QUAL INTEL DISABILITY PROF IV                     ',
#  'TEXAS WORKS SUPERVISOR II                         ',
#  'MOTOR VEHICLE TECHNICIAN III                      ',
#  'CASE MGR I                                        ',
#  'MANAGEMENT ANALYST I                              ',
#  'FOOD SRVC MGR III                                 ',
#  'PHYSICIAN IV                                      ',
#  'CHAPLAINCY SERVICES ASSISTANT                     ',
#  'AC & BOILER OPER II                               ',
#  'MEDICAL TECHNICIAN IV                             ',
#  'DIETETIC TECHN II                                 ',
#  'OMBUDSMAN IV                                      ',
#  'LABORATORY TECHNICIAN II                          ',
#  'BARBER/COSMETOLOGIST                              ',
#  'FAMILY & PROTECT SCVS SUPR II                     ',
#  'COMPUTER OPERATIONS SPEC I                        ',
#  'HUMAN SERVICES TECHNICIAN I                       ',
#  'MEDICAL TECHNICIAN III                            ',
#  'DENTIST II                                        ',
#  'CUSTODIAL MGR III                                 ',
#  'REHABILITATION TEACHER II                         ',
#  'CLAIMS EXAMINER III                               ',
#  'LICENSED VOCATIONAL NURSE II                      ',
#  'FOOD SRVC MGR II                                  ',
#  'REHABILITATION TEACHER III                        ',
#  'REIMBURSEMENT OFFICER II                          ',
#  'DENTAL ASSISTANT I                                ',
#  'VOLUNTEER SERVICES COORD II                       ',
#  'SUBSTANCE ABUSE COUNSELOR II                      ',
#  'MOTOR VEHICLE TECHNICIAN IV                       ',
#  'SECURITY OFFICER I                                ',
#  'CASE MGR III                                      ',
#  'VOLUNTEER SERVICES COORD I                        ',
#  'MAINTENANCE SUPERVISOR II                         ',
#  'HR SPEC II                                        ',
#  'FAMILY & PROTECT SVCS SUPR III                    ',
#  'SOCIAL WORKER III                                 ',
#  'DIETETIC TECHN I                                  ',
#  'TEXAS WORKS ADVISOR IV                            ',
#  'ORTHOPEDIC EQUIP TECHN II                         ',
#  'REIMBURSEMENT OFFICER III                         ',
#  'GROUNDSKEEPER IV                                  ',
#  'OMBUDSMAN VI                                      ',
#  'RECREATION PROG SPEC II                           ',
#  'HEALTH SPECIALIST III                             ',
#  'PROJECT MGT SPECIALIST III                        ',
#  'CONTRACT SPEC I                                   ',
#  'NETWORK SPEC I                                    ',
#  'MEDICAL RESEARCH SPECIALIST                       ',
#  'RECREATION PROG SPEC III                          ',
#  'CERT PEER SPRT SPECIALIST II                      ',
#  'ADULT PROTECTIVE SVCS SPEC II                     ',
#  'PORTFOLIO PROJECT MANAGER II                      ',
#  'CHILD PROTECTIVE SVCS SPEC V                      ',
#  'ELECTRICIAN I                                     ',
#  'LAUNDRY MGR I                                     ',
#  'ORTHOPEDIC EQUIP TECHN III                        ',
#  'INSPECTOR IV                                      ',
#  'DATA BASE ADMINISTRATOR II                        ',
#  'REGISTERED NURSE TRAINEE                          ',
#  'CHILD PROTECTIVE SVCS SPEC IV                     ',
#  'FOOD SRVC MGR IV                                  ',
#  'PSYCHIATRIST II                                   ',
#  'RESEARCH AND STATS TECH I                         ',
#  'DENTAL HYGIENIST II                               ',
#  'RECREATION PROG SPEC I                            ',
#  'DIETETIC & NUTRITION SPEC II                      ',
#  'MEDICAL TECHNOLOGIST I                            ',
#  'DENTIST I                                         ',
#  'CHAPLAIN III                                      ',
#  'PUBLIC HLTH & PRVNT SPEC V                        ',
#  'MACHINIST I                                       ',
#  'HEALTH SPECIALIST I                               ',
#  'EMERG MGT PROGRAM COORD V                         ',
#  'MED TECHNOLOGIST TRAINEE                          ',
#  'TELECOMMUNICATIONS SPEC I                         ',
#  'VOC REHAB CNSLR I                                 ',
#  'LAUNDRY MGR III                                   ',
#  'LICENSED VOCATIONAL NURSE III                     ',
#  'GUARDIANSHIP SUPERVISOR                           ',
#  'RISK MGMT SPEC V                                  ',
#  'STATISTICIAN IV                                   ',
#  'FAMILY & PROTECT SCVS SUPR I                      ',
#  'VOLUNTEER SERVICES COORD IV                       ',
#  'ADULT PROTECTIVE SVCS SPEC V                      ',
#  'PROTECT SRVCS INTAKE SPEC V                       ',
#  'CONTRACT SPEC II                                  ',
#  'PROTECT SRVCS INTAKE SPEC III                     ',
#  'PROTECT SRVCS INTAKE SPEC IV                      ',
#  'CHILD PROTECTIVE SVCS SPEC II                     ',
#  'FAMILY SERVICES SPECIALIST II                     ',
#  'CHILD PROTECTIVE SVCS SPEC I                      ',
#  'ADULT PROTECTIVE SVCS SPEC III                    ',
#  'COMMISSIONER, DFPS                                ',
#  'LEGAL ASSISTANT II                                ',
#  'CHILD PROTECTIVE SVCS SPEC III                    ',
#  'EPIDEMIOLOGIST II                                 ',
#  'PUBLIC HLTH & PRVNT SPEC I                        ',
#  'MEDICAL TECHNICIAN I                              ',
#  'MICROBIOLOGIST IV                                 ',
#  'PUBLIC HEALTH NURSE I                             ',
#  'HEALTH PHYSICIST I                                ',
#  'SANITARIAN III                                    ',
#  'PUBLIC HLTH & PRVNT SPEC II                       ',
#  'MEDICAL TECHNOLOGIST V                            ',
#  'ENVIRONMENTAL PROTECT SPEC I                      ',
#  'VETERINARIAN II                                   ',
#  'MOLECULAR BIOLOGIST IV                            ',
#  'CHEMIST IV                                        ',
#  'PUBLIC HEALTH NURSE III                           ',
#  'HEALTH PHYSICIST III                              ',
#  'HEALTH PHYSICIST II                               ',
#  'MOLECULAR BIOLOGIST III                           ',
#  'MICROBIOLOGIST V                                  ',
#  'CHEMIST V                                         ',
#  'PUBLIC HEALTH NURSE II                            ',
#  'PUBLIC HLTH & PRVNT SPEC IV                       ',
#  'COMMISSIONER, DSHS                                ',
#  'SANITARIAN II                                     ',
#  'MOLECULAR BIOLOGIST V                             ',
#  'EPIDEMIOLOGIST I                                  ',
#  'SOCIAL WORKER II                                  ',
#  'MICROBIOLOGIST III                                ',
#  'VETERINARIAN III                                  ',
#  'SOCIAL WORKER IV                                  ',
#  'CHIEF SCIENTIFIC OFFICER                          ',
#  'EXECUTIVE DIRECTOR, TAHC                          ',
#  'ENGINEERING AIDE                                  ',
#  'TRANS MAINT SPEC IV                               ',
#  'ENGINEERING TECHNICIAN I                          ',
#  'FERRYBOAT DECKHAND I                              ',
#  'FERRYBOAT SPECIALIST III                          ',
#  'ENGINEERING TECHNICIAN II                         ',
#  'DISTRICT ENGINEER                                 ',
#  'ARCHEOLOGIST III                                  ',
#  'RIGHT OF WAY AGENT IV                             ',
#  'FERRYBOAT SPECIALIST I                            ',
#  'FERRYBOAT DECKHAND II                             ',
#  'AIRCRAFT MECHANIC I                               ',
#  'ENGINEERING TECHNICIAN III                        ',
#  'RIGHT OF WAY AGENT VI                             ',
#  'AIRCRAFT MECHANIC II                              ',
#  'FERRYBOAT SPECIALIST II                           ',
#  'RIGHT OF WAY AGENT V                              ',
#  'COMMISSION MEMBERS                                ',
#  'ENVIRONMENTAL PROTECT SPEC II                     ',
#  'PLUMBER IIII                                      ',
#  'RADIO COMMUNICATIONS TECH I                       ',
#  'TRANS MAINT SPEC V                                ',
#  'LAND SURVEYOR IV                                  ',
#  'LAND SURVEYOR II                                  ',
#  'AIRCRAFT PILOT I                                  ',
#  'SAFETY OFFCR III                                  ',
#  'ELECTRICIAN IV                                    ',
#  'ENGINEERING SPECIALIST I                          ',
#  'FERRYBOAT SPECIALIST IV                           ',
#  'AIRCRAFT MECHANIC III                             ',
#  'EXECUTIVE ASST I                                  ',
#  'PAYROLL SPECIALIST V                              ',
#  'AIRCRAFT PILOT II                                 ',
#  'DATA ANALYST I                                    ',
#  'ENGINEERING TECHNICIAN IV                         ',
#  'PAYROLL SPECIALIST III                            ',
#  'RIGHT OF WAY AGENT III                            ',
#  'FLEET MANAGER II                                  ',
#  'JUVENILE CORREC OFFCR III                         ',
#  'PRINC, TEACHERS, & COACHES                        ',
#  'DORM SUPERVISOR I                                 ',
#  'YOUTH FACILITY ASST SUPT                          ',
#  'YOUTH FACILITY SUPERINTENDENT                     ',
#  'HALFWAY HOUSE SUPERINTENDENT                      ',
#  'POLICE COMMUNICATIONS OPER III                    ',
#  'JUVENILE CORREC OFFCR I                           ',
#  'HEALTH SPECIALIST IV                              ',
#  'TEACHER AIDE I                                    ',
#  'TEACHER AIDE II                                   ',
#  'CORREC OFFCR III                                  ',
#  'CORREC  OFFICER IV                                ',
#  'PAROLE OFFCR V                                    ',
#  'ASST WARDEN                                       ',
#  'AGRICULTURE SPEC II                               ',
#  'PAROLE OFFCR IV                                   ',
#  'INDUSTRIAL SPEC II                                ',
#  'PAYROLL ASSISTANT                                 ',
#  'REGIONAL MANAGER- OIG                             ',
#  'INVESTIGATOR IV - OIG                             ',
#  'COUNSEL SUBSTITUTE I                              ',
#  'WARDEN I                                          ',
#  'WARDEN II                                         ',
#  'SUBSTANCE ABUSE COUNSELOR I                       ',
#  'INDUSTRIAL SPEC III                               ',
#  'H/SRVC SPEC V                                     ',
#  'COUNSEL SUBSTITUTE II                             ',
#  'REGIONAL SUPERVISOR- OIG                          ',
#  'INVESTIGATOR III - OIG                            ',
#  'EX DIRECTOR TDCJ                                  ',
#  'LEGAL ASSISTANT I                                 ',
#  'PAROLE OFFCR I                                    ',
#  'PAROLE OFFCR II                                   ',
#  'EQUIPMENT MAINT TECH II                           ',
#  'CHAIR,PARDONS AND PAROLES                         ',
#  'PAROLE BOARD MEMBER                               ',
#  'CHIEF INSPECTOR - OIG                             ',
#  'CERT PEER SPRT SPECIALIST III                     ',
#  'PORTFOLIO MANAGER VI                              ',
#  'COMMISSIONER, TEXAS EDUCATION                     ',
#  'PORTFOLIO MANAGER II                              ',
#  'PSF CHIEF INVESTMENT OFFICER                      ',
#  'TEACHER,PRINCIPALS,SUPERVISORS                    ',
#  'SUPERINTENDENT                                    ',
#  'PRINCIPALS, TEACHERS, SPRVSR                      ',
#  'INTERPRETER II                                    ',
#  'PROGRAM DIRECTOR                                  ',
#  'INTERNAL AUDIT LEAD                               ',
#  '19 EXECUTIVE ASSISTANT                            ',
#  '21 SYSTEMS ADMINISTRATOR III                      ',
#  '20 PROGRAM SPECIALIST III                         ',
#  'MANAGER                                           ',
#  'DEPUTY CHIEF OF STAFF                             ',
#  'ASSISTANT COMMISSIONER                            ',
#  'ASSISTANT DIRECTOR                                ',
#  '24 SYSTEM ANALYST VI                              ',
#  'SENIOR NETWORK ANALYST                            ',
#  'SENIOR PROGRAM DIRECTOR                           ',
#  'SENIOR PROJECT MANAGER                            ',
#  'TECHNICAL WRITER                                  ',
#  '21 BUSINESS ANALYST                               ',
#  'COMPLIANCE SPECIALIST                             ',
#  'DEPUTY ASST COMMISSIONER                          ',
#  'PROGRAM MANAGER                                   ',
#  'SPECIAL PROJECTS DIRECTOR                         ',
#  'HUMAN RESOURCES SPECIALIST IV                     ',
#  'SOFTWARE QUALITY ASSURANCE SPE                    ',
#  '23 SYSTEMS ADMINISTRATOR IV                       ',
#  'TECHNICAL WRITER/TRAINER                          ',
#  'DEPUTY COMMISSIONER                               ',
#  'DEP COM APP/CHIEF ACAD OFFICER                    ',
#  'ASST GENERAL COUNSEL                              ',
#  'DATABASE ADMINISTRATOR                            ',
#  ...]

# %% [markdown]
# ## Removing outliers in salary

# %%
features = ['HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL']

# Creating subplots for box plots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Creating box plots for each feature in subplots
for i, feature in enumerate(features):
    sns.boxplot(x=df[feature], ax=axes[i])
    axes[i].set_title(f'Boxplot for {feature}')
    axes[i].set_xlabel('')

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %%
def find_boundaries(variable):

    q1 = df[variable].quantile(0.25)
    q3 = df[variable].quantile(0.75)
    iqr = q3 - q1
    lower_range = q1 - 1.5 * iqr #used to find the minimum value
    upper_range = q3 + 1.5 * iqr#max value
    return lower_range, upper_range

# %%
lower_ANNUAL, upper_ANNUAL = find_boundaries('ANNUAL')
print(lower_ANNUAL, upper_ANNUAL)

#capp the outlier / censoring the outlier
df.ANNUAL = np.where( df.ANNUAL > upper_ANNUAL, upper_ANNUAL, df.ANNUAL )
df.ANNUAL = np.where( df.ANNUAL < lower_ANNUAL, lower_ANNUAL, df.ANNUAL )
# Out:
# 3010.6200000000026 91617.18

# %%
lower_MONTHLY, upper_MONTHLY = find_boundaries('MONTHLY')
print(lower_MONTHLY, upper_MONTHLY)

#capp the outlier / censoring the outlier
df.MONTHLY = np.where( df.MONTHLY > upper_MONTHLY, upper_MONTHLY, df.MONTHLY )
df.MONTHLY = np.where( df.MONTHLY < lower_MONTHLY, lower_MONTHLY, df.MONTHLY )
# Out:
# 250.88499999999976 7634.765000000001

# %%
features = ['HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL']

# Creating subplots for box plots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Creating box plots for each feature in subplots
for i, feature in enumerate(features):
    sns.boxplot(x=df[feature], ax=axes[i])
    axes[i].set_title(f'Boxplot for {feature}')
    axes[i].set_xlabel('')

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# Observing the range of the boxplots, we say that the outliers are removed from the original data. The new 'outliers' that we can see in the variables are moderate outliers that lied within the upper whisker-lower whisker range before removing the original outliers. It can be seen that the variable Monthly& Annual has no new outliers.
#
# It is up to the discretion of the data scientist, to remove them or not; and maybe decided after evaluating the model performance.
#
# A crude way to know whether the outliers have been removed or not is to check the dimensions of the data. If the dimension is reduced it implies that the outliers are removed.

# %%
sns.histplot(x = 'ANNUAL', data = df, kde = True)
# Out:
# <Axes: xlabel='ANNUAL', ylabel='Count'>

# %%
df.shape
# Out:
# (149481, 16)

# %%
df.columns
# Out:
# Index(['AGENCY', 'AGENCY NAME', 'LAST NAME', 'FIRST NAME', 'MI', 'CLASS CODE',
#        'CLASS TITLE', 'ETHNICITY', 'GENDER', 'STATUS', 'EMPLOY DATE',
#        'HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL', 'STATE NUMBER'],
#       dtype='object')

# %% [markdown]
# ## Correlation between contious features

# %%
con_features = df[['HRLY RATE', 'HRS PER WK', 'MONTHLY', 'ANNUAL']].corr()
con_features
# Out:
#             HRLY RATE  HRS PER WK   MONTHLY    ANNUAL
# HRLY RATE    1.000000   -0.337784  0.071839  0.071839
# HRS PER WK  -0.337784    1.000000  0.132252  0.132252
# MONTHLY      0.071839    0.132252  1.000000  1.000000
# ANNUAL       0.071839    0.132252  1.000000  1.000000

# %%
sns.heatmap(con_features, annot  = True,cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# #### As we expected mothly and Annual features are highly correlated, so can drop any one of the feature, we'll drop monthly feature

# %%
df.drop('MONTHLY', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    AGENCY                                        AGENCY NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
# 2     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3     212  OFFICE OF COURT ADMINISTRATION                ...
# 4     696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
#
#                         LAST NAME                      FIRST NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
# 2  SPECIA JR                       JOHN                            J
# 3  SPECIA JR                       JOHN                            J
# 4  ONTIVEROS                       ESTHER
#
#   CLASS CODE                                        CLASS TITLE  \
# 0   JD25      JUDGE, RETIRED                                ...
# 1   3524      GENERAL COUNSEL IV                            ...
# 2   JD25      JUDGE, RETIRED                                ...
# 3   3524      GENERAL COUNSEL IV                            ...
# 4   4504      CORREC  OFFICER IV                            ...
#
#          ETHNICITY           GENDER                                    STATUS  \
# 0  WHITE            MALE             URP - UNCLASSIFIED REGULAR PART-TIME
# 1  WHITE            MALE             CTP - CLASSIFIED TEMPORARY PART-TIME
# 2  WHITE            MALE             URP - UNCLASSIFIED REGULAR PART-TIME
# 3  WHITE            MALE             CTP - CLASSIFIED TEMPORARY PART-TIME
# 4  HISPANIC         FEMALE           CRF - CLASSIFIED REGULAR FULL-TIME
#
#   EMPLOY DATE  HRLY RATE  HRS PER WK    ANNUAL  STATE NUMBER
# 0    02/18/88   75.96150        29.0  91617.18        127717
# 1    02/01/15   81.04454         4.0  16857.24        127717
# 2    02/01/20   75.96150        29.0  91617.18         59115
# 3    09/01/18   81.04453         4.0  16857.24         59115
# 4    06/29/20    0.00000        40.0  39411.24        165030

# %% [markdown]
# ## **TASK 3**
# ### What departments/roles have the biggest wage disparities between
# managers and employees?

# %% [markdown]
# ## Wage disparities

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(x='AGENCY', y='ANNUAL', data=df, hue='STATUS')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.pivot_table(df, index = ['AGENCY NAME','STATUS','CLASS TITLE'], values = 'ANNUAL')
# Out:
#                                                                                                                                                   ANNUAL
# AGENCY NAME                                        STATUS                                   CLASS TITLE
# ALCOHOLIC BEVERAGE COMMISSION                      CRF - CLASSIFIED REGULAR FULL-TIME       ACCOUNTANT I                                        39263.52
#                                                                                             ACCOUNTANT II                                       42500.04
#                                                                                             ACCOUNTANT IV                                       51000.00
#                                                                                             ACCOUNTANT VI                                       63543.48
#                                                                                             ACCTS EXAM I                                        36000.00
# ...                                                                                                                                                  ...
# WATER DEVELOPMENT BOARD                            CRP - CLASSIFIED REGULAR PART-TIME       DATA BASE ADMINISTRATOR IV                          84430.32
#                                                                                             ENGINEER IV                                         62893.68
#                                                    CTF - CLASSIFIED TEMPORARY FULL-TIME     ADMINISTRATIVE ASST I                               31980.00
#                                                    ERF - EXEMPT REGULAR FULL-TIME           BOARD MEMBER                                        91617.18
#                                                                                             EXECUTIVE ADMINISTRATOR, WATER                      91617.18
#
# [7700 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['AGENCY NAME'], values = ['CLASS TITLE'], aggfunc = 'count')
# Out:
#                                                     CLASS TITLE
# AGENCY NAME
# ALCOHOLIC BEVERAGE COMMISSION                               642
# BOARD OF ARCHITECTURAL EXAMINERS                             19
# BOARD OF CHIROPRACTIC EXAMINERS                              10
# BOARD OF DENTAL EXAMINERS                                    56
# BOARD OF EXAMINERS OF PSYCHOLOGISTS                          15
# ...                                                         ...
# THIRD COURT OF APPEALS DISTRICT                              32
# THIRTEENTH COURT OF APPEALS DISTRICT                         30
# TREASURY SAFEKEEPING TRUST COMPANY                           71
# TWELFTH COURT OF APPEALS DISTRICT                            15
# WATER DEVELOPMENT BOARD                                     340
#
# [113 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['AGENCY NAME','CLASS TITLE','STATUS'], values = 'ANNUAL')
# Out:
#                                                                                                                                                   ANNUAL
# AGENCY NAME                                        CLASS TITLE                                        STATUS
# ALCOHOLIC BEVERAGE COMMISSION                      ACCOUNTANT I                                       CRF - CLASSIFIED REGULAR FULL-TIME        39263.52
#                                                    ACCOUNTANT II                                      CRF - CLASSIFIED REGULAR FULL-TIME        42500.04
#                                                    ACCOUNTANT IV                                      CRF - CLASSIFIED REGULAR FULL-TIME        51000.00
#                                                    ACCOUNTANT VI                                      CRF - CLASSIFIED REGULAR FULL-TIME        63543.48
#                                                    ACCTS EXAM I                                       CRF - CLASSIFIED REGULAR FULL-TIME        36000.00
# ...                                                                                                                                                  ...
# WATER DEVELOPMENT BOARD                            SYSTEMS ANALYST VI                                 CRF - CLASSIFIED REGULAR FULL-TIME        91617.18
#                                                    SYSTEMS SUPPORT SPECIALIST II                      CRF - CLASSIFIED REGULAR FULL-TIME        48000.00
#                                                    SYSTEMS SUPPORT SPECIALIST III                     CRF - CLASSIFIED REGULAR FULL-TIME        52722.36
#                                                    WEB ADMINISTRATOR III                              CRF - CLASSIFIED REGULAR FULL-TIME        72381.12
#                                                    WEB ADMINISTRATOR V                                CRF - CLASSIFIED REGULAR FULL-TIME        87178.08
#
# [7700 rows x 1 columns]

# %%
pivot_table=pd.pivot_table(df, index = ['STATUS','CLASS TITLE'], values = 'ANNUAL')

# %%
wage_disparities_department = pivot_table.max(axis=1) - pivot_table.min(axis=1)
wage_disparities_job_title = pivot_table.max(axis=0) - pivot_table.min(axis=0)

# %%
average_salary_department = pivot_table.mean(axis=1)
relative_disparities_department = (pivot_table.max(axis=1) - pivot_table.min(axis=1)) / average_salary_department * 100

# %%
# Print the pivot table
print("Pivot Table - Average Salary by Department and Job Title:")
print(pivot_table)

# Calculate wage disparities
wage_disparities_department = pivot_table.max(axis=1) - pivot_table.min(axis=1)
wage_disparities_job_title = pivot_table.max(axis=0) - pivot_table.min(axis=0)

print("\nWage Disparities by Department:")
print(wage_disparities_department)

print("\nWage Disparities by Job Title:")
print(wage_disparities_job_title)
# Out:
# Pivot Table - Average Salary by Department and Job Title:
#                                                                                                    ANNUAL
# STATUS                                   CLASS TITLE
# CRF - CLASSIFIED REGULAR FULL-TIME       AC & BOILER OPER I                                  29463.032000
#                                          AC & BOILER OPER II                                 37501.170000
#                                          AC & BOILER OPER III                                48749.808000
#                                          AC & BOILER OPER IV                                 49878.480000
#                                          ACCOUNTANT I                                        38364.777931
# ...                                                                                                   ...
# UTP - UNCLASSIFIED TEMPORARY PART-TIME   LEG. SERVICE/MAINTENANCE                             3393.720000
#                                          LEGISLATIVE ADMIN. SUPPORT                          15255.960000
#                                          LEGISLATIVE PARAPROFESSIONAL                        36000.000000
#                                          LEGISLATIVE PROFESSIONAL                            28992.000000
#                                          RESEARCH SPECIAL ASSTISTANT                         56289.000000
#
# [1811 rows x 1 columns]
#
# Wage Disparities by Department:
# STATUS                                    CLASS TITLE
# CRF - CLASSIFIED REGULAR FULL-TIME        AC & BOILER OPER I                                    0.0
#                                           AC & BOILER OPER II                                   0.0
#                                           AC & BOILER OPER III                                  0.0
#                                           AC & BOILER OPER IV                                   0.0
#                                           ACCOUNTANT I                                          0.0
#                                                                                                ...
# UTP - UNCLASSIFIED TEMPORARY PART-TIME    LEG. SERVICE/MAINTENANCE                              0.0
#                                           LEGISLATIVE ADMIN. SUPPORT                            0.0
#                                           LEGISLATIVE PARAPROFESSIONAL                          0.0
#                                           LEGISLATIVE PROFESSIONAL                              0.0
#                                           RESEARCH SPECIAL ASSTISTANT                           0.0
# Length: 1811, dtype: float64
#
# Wage Disparities by Job Title:
# ANNUAL    88223.46
# dtype: float64

# %%
max_disparity_department = wage_disparities_department.idxmax()
max_disparity_value_department = wage_disparities_department.max()

max_disparity_job_title = wage_disparities_job_title.idxmax()
max_disparity_value_job_title = wage_disparities_job_title.max()

# %%
print(f"The department with the highest wage disparity is '{max_disparity_department}' "
      f"with a disparity of {max_disparity_value_department}")

print(f"The job title with the highest wage disparity is '{max_disparity_job_title}' "
      f"with a disparity of {max_disparity_value_job_title}")
# Out:
# The department with the highest wage disparity is '('CRF - CLASSIFIED REGULAR FULL-TIME      ', 'AC & BOILER OPER I                                ')' with a disparity of 0.0
# The job title with the highest wage disparity is 'ANNUAL' with a disparity of 88223.46

# %% [markdown]
# ### **TASK 3**
# ### Have salaries and total compensations for some roles/ departments/
# ### head-count changed over time?

# %% [markdown]
# ## Change in compensation over time

# %%
df["year_of_employment"] = pd.DatetimeIndex(df['EMPLOY DATE']).year

# %%
df['years_of_service'] = 2024- df['year_of_employment']

# %%
df['years_of_service'] = df['years_of_service'].clip(lower=0)

# %%
plt.figure(figsize=(15,9))
sns.lineplot(x='years_of_service', y='ANNUAL',hue ='STATUS', data= df)
plt.legend()
plt.show()

# %%
df.pivot_table(values = ['ANNUAL', 'years_of_service'], index = ['CLASS TITLE','STATUS'], aggfunc = 'mean')
# Out:
#                                                                                                    ANNUAL  \
# CLASS TITLE                                        STATUS
# 14 CUSTOMER SERVICES REP                           URF - UNCLASSIFIED REGULAR FULL-TIME      40403.177143
# 19 EXECUTIVE ASSISTANT                             URF - UNCLASSIFIED REGULAR FULL-TIME      64992.960000
# 20 PROGRAM SPECIALIST III                          URF - UNCLASSIFIED REGULAR FULL-TIME      59445.274286
# 21 BUSINESS ANALYST                                URF - UNCLASSIFIED REGULAR FULL-TIME      64422.800000
# 21 SYSTEMS ADMINISTRATOR III                       URF - UNCLASSIFIED REGULAR FULL-TIME      58375.020000
# ...                                                                                                   ...
# WRITING SPEC I                                     URF - UNCLASSIFIED REGULAR FULL-TIME      39249.960000
# WRITING SPEC II                                    URF - UNCLASSIFIED REGULAR FULL-TIME      42999.960000
# WRITING SPECIALIST III                             URF - UNCLASSIFIED REGULAR FULL-TIME      49451.920000
# YOUTH FACILITY ASST SUPT                           CRF - CLASSIFIED REGULAR FULL-TIME        75165.240000
# YOUTH FACILITY SUPERINTENDENT                      CRF - CLASSIFIED REGULAR FULL-TIME        91170.300000
#
#                                                                                              years_of_service
# CLASS TITLE                                        STATUS
# 14 CUSTOMER SERVICES REP                           URF - UNCLASSIFIED REGULAR FULL-TIME              5.857143
# 19 EXECUTIVE ASSISTANT                             URF - UNCLASSIFIED REGULAR FULL-TIME              7.500000
# 20 PROGRAM SPECIALIST III                          URF - UNCLASSIFIED REGULAR FULL-TIME             13.571429
# 21 BUSINESS ANALYST                                URF - UNCLASSIFIED REGULAR FULL-TIME             20.333333
# 21 SYSTEMS ADMINISTRATOR III                       URF - UNCLASSIFIED REGULAR FULL-TIME              6.500000
# ...                                                                                                       ...
# WRITING SPEC I                                     URF - UNCLASSIFIED REGULAR FULL-TIME              6.500000
# WRITING SPEC II                                    URF - UNCLASSIFIED REGULAR FULL-TIME             10.000000
# WRITING SPECIALIST III                             URF - UNCLASSIFIED REGULAR FULL-TIME             17.333333
# YOUTH FACILITY ASST SUPT                           CRF - CLASSIFIED REGULAR FULL-TIME                9.800000
# YOUTH FACILITY SUPERINTENDENT                      CRF - CLASSIFIED REGULAR FULL-TIME                8.200000
#
# [1811 rows x 2 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame and includes 'ANNUAL', 'years_of_service', 'CLASS TITLE', and 'STATUS' columns

# Create a pivot table to calculate mean annual wages and years of service for each role and status
pivot_table = df.pivot_table(values=['ANNUAL', 'years_of_service'], index=['CLASS TITLE', 'STATUS'], aggfunc='mean')

# Reset index to make 'CLASS TITLE' and 'STATUS' columns instead of index
pivot_table = pivot_table.reset_index()

# Calculate mean salary and compensation over time
# Here, we assume 'years_of_service' represents time; alternatively, you can use other time-related columns if available
mean_salaries_over_time = df.groupby('years_of_service')['ANNUAL'].mean().reset_index()

# Display the results
print(mean_salaries_over_time)
# Out:
#     years_of_service        ANNUAL
# 0                  0  50053.465714
# 1                  4  40036.313718
# 2                  5  42003.269960
# 3                  6  44460.230846
# 4                  7  43331.861096
# 5                  8  51399.400899
# 6                  9  51008.676091
# 7                 10  52163.484908
# 8                 11  53243.106643
# 9                 12  53071.234279
# 10                13  52651.864203
# 11                14  54235.212899
# 12                15  52787.178736
# 13                16  52932.487064
# 14                17  56464.667128
# 15                18  54677.482391
# 16                19  57484.583347
# 17                20  55192.510417
# 18                21  61242.688324
# 19                22  61327.865279
# 20                23  59270.271289
# 21                24  60423.775654
# 22                25  62473.852931
# 23                26  62668.528463
# 24                27  63059.509375
# 25                28  61142.714902
# 26                29  63478.131318
# 27                30  65517.453103
# 28                31  65313.240000
# 29                32  64606.966967
# 30                33  69253.888670
# 31                34  70438.868333
# 32                35  74496.167638
# 33                36  77512.249302
# 34                37  72598.451304
# 35                38  75028.274026
# 36                39  71346.609286
# 37                40  72236.107925
# 38                41  78179.398537
# 39                42  79365.260000
# 40                43  79345.518621
# 41                44  79637.154000
# 42                45  76212.200000
# 43                46  76971.912000
# 44                47  84088.500000
# 45                48  81909.504000
# 46                49  91617.180000

# %% [markdown]
# The pivot table provides a detailed view of how salaries and tenure vary across different roles (CLASS TITLE) and statuses (STATUS). It helps in identifying disparities or trends within specific job categories.
#
# **Career Progression Analysis**:
# The mean_salaries_over_time analysis allows you to understand how salaries evolve over time as employees accumulate more years of service. This can reveal patterns such as salary growth trajectories and potential anomalies.

# %% [markdown]
# ### Converting categorical column to Numerical columns

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

for i in range(0,df.shape[1]):
    if df.dtypes[i]=='object':
        df[df.columns[i]] = label.fit_transform(df[df.columns[i]])


df
# Out:
#         AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  \
# 0          241           17      30461       15274  22        1409
# 1          212           48      30461       15274  22         616
# 2          241           17      33197       10053  10        1409
# 3          212           48      33197       10053  10         616
# 4          696           88      26462        6953   0         810
# ...        ...          ...        ...         ...  ..         ...
# 149476     809           76      37355       10053  16        1042
# 149477     809           76      37780        7024   1          84
# 149478     809           76      38068        5571   3           4
# 149479     809           76      38313        6089  18         278
# 149480     809           76      38652        7720  16           4
#
#         CLASS TITLE  ETHNICITY  GENDER  STATUS  EMPLOY DATE  HRLY RATE  \
# 0               711          5       1       8          947   75.96150
# 1               560          5       1       4          605   81.04454
# 2               711          5       1       8          610   75.96150
# 3               560          5       1       4         4268   81.04453
# 4               292          3       0       0         3209    0.00000
# ...             ...        ...     ...     ...          ...        ...
# 149476         1198          5       1       0         5308    0.00000
# 149477         1404          5       0       0         3444    0.00000
# 149478          324          5       1       1         5062   12.93000
# 149479         1007          5       1       0         4677    0.00000
# 149480          324          5       0       1          898   11.74000
#
#         HRS PER WK    ANNUAL  STATE NUMBER  year_of_employment  \
# 0             29.0  91617.18        127717                1988
# 1              4.0  16857.24        127717                2015
# 2             29.0  91617.18         59115                2020
# 3              4.0  16857.24         59115                2018
# 4             40.0  39411.24        165030                2020
# ...            ...       ...           ...                 ...
# 149476        40.0  34788.00        770781                2017
# 149477        40.0  66000.00        847431                2015
# 149478        20.0  13447.20         34266                2012
# 149479        40.0  68929.92        123490                1989
# 149480        20.0  12209.52        103583                2012
#
#         years_of_service
# 0                     36
# 1                      9
# 2                      4
# 3                      6
# 4                      4
# ...                  ...
# 149476                 7
# 149477                 9
# 149478                12
# 149479                35
# 149480                12
#
# [149481 rows x 17 columns]

# %%
# X= df.drop(['AGENCY','AGENCY NAME','LAST NAME' ,'FIRST NAME','MI','EMPLOY DATE','STATE NUMBER','year_of_employment', 'ANNUAL'], axis=1)
# y=df['ANNUAL']

# %%
X_new =df.drop(['EMPLOY DATE','ANNUAL', 'STATE NUMBER'], axis=1)
y=df[['ANNUAL']]

# %%
X_new.head()
# Out:
#    AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  CLASS TITLE  \
# 0     241           17      30461       15274  22        1409          711
# 1     212           48      30461       15274  22         616          560
# 2     241           17      33197       10053  10        1409          711
# 3     212           48      33197       10053  10         616          560
# 4     696           88      26462        6953   0         810          292
#
#    ETHNICITY  GENDER  STATUS  HRLY RATE  HRS PER WK  year_of_employment  \
# 0          5       1       8   75.96150        29.0                1988
# 1          5       1       4   81.04454         4.0                2015
# 2          5       1       8   75.96150        29.0                2020
# 3          5       1       4   81.04453         4.0                2018
# 4          3       0       0    0.00000        40.0                2020
#
#    years_of_service
# 0                36
# 1                 9
# 2                 4
# 3                 6
# 4                 4

# %%
y.head()
# Out:
#      ANNUAL
# 0  91617.18
# 1  16857.24
# 2  91617.18
# 3  16857.24
# 4  39411.24

# %% [markdown]
# #  Model selection and model preparation

# %%
X_new.head()
# Out:
#    AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  CLASS TITLE  \
# 0     241           17      30461       15274  22        1409          711
# 1     212           48      30461       15274  22         616          560
# 2     241           17      33197       10053  10        1409          711
# 3     212           48      33197       10053  10         616          560
# 4     696           88      26462        6953   0         810          292
#
#    ETHNICITY  GENDER  STATUS  HRLY RATE  HRS PER WK  year_of_employment  \
# 0          5       1       8   75.96150        29.0                1988
# 1          5       1       4   81.04454         4.0                2015
# 2          5       1       8   75.96150        29.0                2020
# 3          5       1       4   81.04453         4.0                2018
# 4          3       0       0    0.00000        40.0                2020
#
#    years_of_service
# 0                36
# 1                 9
# 2                 4
# 3                 6
# 4                 4

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new,y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((119584, 14), (29897, 14))

# %% [markdown]
# ### Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %% [markdown]
# ## Model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
def fitAndPredict(model):
    """The following code makes faster to evaluate a model
    automating the fit and accuracy process"""

    model.fit(X_train_scaled, y_train)
    prediction = model.predict(X_test_scaled)
    from sklearn.model_selection import cross_val_score
    scores = cross_val_score(model, X_train_scaled, y_train, cv=5)
    print("Train R2 :", model.score(X_train_scaled, y_train))
    print("Test R2: ", model.score(X_test_scaled, y_test))
    print("Cross Validation Score: ", scores.mean())
    return 'model ran succesfully!'

# %%
model1 = LinearRegression()
model2 = Lasso()
model3 = Ridge()
model4 = XGBRegressor()
models = [model1,model2, model3, model4]
i = 0
for model in models:
    i +=1
    print("Model ", i,":", model)
    print(fitAndPredict(model))
# Out:
# Model  1 : LinearRegression()
# Train R2 : 0.2626075107899771
# Test R2:  0.2646628291471895
# Cross Validation Score:  0.2622362055358264
# model ran succesfully!
# Model  2 : Lasso()
# Train R2 : 0.2625789179996576
# Test R2:  0.265076890074589
# Cross Validation Score:  0.2621990256416617
# model ran succesfully!
# Model  3 : Ridge()
# Train R2 : 0.2626074901479889
# Test R2:  0.2646763787116597
# Cross Validation Score:  0.26223617347668754
# model ran succesfully!
# Model  4 : XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
# Train R2 : 0.9278273648827506
# Test R2:  0.9147313633783871
# Cross Validation Score:  0.9153221986419939
# model ran succesfully!

# %%
model4.score(X_train_scaled, y_train)
# Out:
# 0.9278273648827506

# %%
y_preds = model4.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score,mean_absolute_error

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_preds)) #RSME
print(rmse)
print(mean_squared_error(y_test, y_preds))
print(r2_score(y_test, y_preds))
# Out:
# 5414.53038616765
# 29317139.302732807
# 0.9147313633783871

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest_model = RandomForestRegressor(n_estimators=100, verbose=0, random_state=0)
random_forest_model.fit(X_train_scaled,y_train)
forest_pred = random_forest_model.predict(X_test_scaled)
print(mean_absolute_error(forest_pred, y_test))
print(mean_squared_error(forest_pred, y_test))
# Out:
# 2380.918138816621
# 20094052.839066155

# %%
print(r2_score(y_test, forest_pred))
# Out:
# 0.9415566276062239

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# ## TASK 1
# ### EDA is performed and here is the key insights and overall data analysis report
#
# 1. Introduction
#
# This report analyzes a salary dataset encompassing positions across all 113 agencies in the Texas state government. The dataset includes 149,481 data points with 21 features, focusing on understanding salary distributions, workforce demographics, and employment characteristics.
#
# 2. Dataset Overview
#
# Features: The dataset comprises 21 features, including both numerical (8) and categorical (13) variables.
#
# Target Variable: Annual salary is chosen as the target variable, with monthly salary considered as a feature.
#
# Data Quality: Some columns such as "duplicated", "multiple_full_time_jobs", "combined_multiple_jobs", "summed_annual_salary", and "hide_from_search" contain null values and lack variance, with "multiple_full_time_jobs" having a standard deviation of 0, indicating no variability.
#
# 3. Salary and Work Characteristics
#
# Salary Range: Employees' annual salaries range from $600 to $553,500, showcasing a diverse salary spectrum.
#
# Working Hours: Weekly working hours range from 1 hour to a maximum of 70 hours per employee.
#
# Distribution: Monthly salaries exhibit a left-skewed distribution, while hourly rates follow a similar pattern, with a majority earning between $0 to $8 per hour.
#
# 4. Workforce Demographics
#
# Ethnicity and Gender: The dataset predominantly represents White individuals and has a higher proportion of female employees.
#
# Employment Type: Most employees work in classified regular full-time positions, indicating stability in employment status.
#
# Agency Distribution: The Health and Human Services Commission employs the highest number of individuals (approximately 36,667), followed by the Texas Department of Criminal Justice (approximately 35,926).
#
# 5. Insights and Recommendations
#
# Insights: The analysis highlights the need for further exploration into factors influencing salary disparities across demographics and agencies. Strategies should focus on enhancing diversity and equity in employment practices.
#
# Recommendations: Implement data preprocessing steps to handle null values and remove redundant columns with no variance. Conduct deeper analyses to understand the impact of variables such as ethnicity and gender on salary differentials.
#
# 6. Conclusion
#
# In conclusion, the dataset provides valuable insights into salary distributions, workforce demographics, and employment characteristics within the Texas state government. Further analysis and strategic initiatives can leverage these insights to optimize workforce management practices and ensure fair employment conditions across agencies.

# %% [markdown]
# ## TASK 2
# ### model creation
# We built 5 predictive models
# 1. LinearRegression
# 2. Ridge
# 3. Lasso
# 4. XGBRegressor
# 5. RandomForestRegressor
#
# After evaluating the multiple models we getting highest r2 score of **94.15%**
# and least mean squared error for the RandomForestRegressor model so we are concluding that **RandomForestRegressor** is the best model which will help theTexas state government team to know the payroll information of employees of the state of Texas.

# %% [markdown]
# ## TASK 3
#
# a) outliers in the salaries
#
# To determine the outliers in the salary, we can consider the hourly rates and the mean average salary, plotted against the agency and status of the workforce.
#
# If we observe the plotted graph of average hourly rate against the agency name, we can see that the “COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY”, has a distinct peak, almost six times more than the other agencies in the mix.
# Next, if we check the graph of average hourly rate plotted against the status, we observe that EXEMPT REGULAR PART-TIME, ERP and UNCLASSIFIED REGULAR PART-TIME, URP categories are exceeding other categories around 5 and 3 times respectively. This can be further observed in the box plot between Annual and status.
#
# b) departments/roles have the biggest wage disparities between
# managers and employees.
#
# The department with the highest wage disparity is ('CRF - CLASSIFIED REGULAR FULL-TIME', 'AC & BOILER OPER I') with the highest wage disparity in 'ANNUAL'  with a disparity of 88223.46
#
# c) salaries and total compensations for some roles/ departments/
# head-count changed over time
#
# The pivot table provides a detailed view of how salaries and tenure vary across different roles (CLASS TITLE) and statuses (STATUS). It helps in identifying disparities or trends within specific job categories.
#
# Career Progression Analysis: The mean_salaries_over_time analysis allows you to understand how salaries evolve over time as employees accumulate more years of service. This can reveal patterns such as salary growth trajectories and potential anomalies.

# %% [markdown]
# ### There are some of challenges that as a team we face are :
#
# 1) Poor Quality of Data : One of the significant issues our team face is the absence of good quality data. Unclean and noisy data can make the whole process extremely exhausting. There is null values in "duplicated", "comb_mlti_jobs", "summed_annual_salary", "hide_from_search" In many features there is a lack of variation like the standard deviation for "multiple full time jobs" column is 0, means no variance in the data. to overcome this issue we drop some features because having more then 96% of missing values, we are ignoring those columns.
#
# 2) Slow process : The machine learning models are highly efficient in providing accurate results, but it takes a tremendous amount of time.At the time of exploratory data analysis process it take lot of time when analyse bivariate and multivariate analysis. So to overcome this issue we did bivariate analysis of relevent featues only.
#
# 3) Underfitting of Training Data : This process occurs when data is unable to establish an accurate relationship between input and output variables.It signifies the data is too simple to establish a precise relationship. To overcome this issue: Maximize the training time,add relevent features to the data, increasing the training time of model.
#
# 4) Overfitting of Training Data : Overfitting refers to ML model trained with a massive amount of data that negatively affect its performance. We can tackle this issue by:Analyzing the data with perfection, remove outliers in the training set, remove unwanted feature. For particular agency_name their will be unique agency_code, so we are droping agency_name and also We dropped last name, first name, MI and emp_date because these are not relevent features for our model creation.
